# %%
# !pip install --upgrade pip
# !pip install numpy==1.24.3
# !pip install torch==2.0.0 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install torch-geometric
# !pip install torch-scatter torch-sparse torch-cluster -f https://data.pyg.org/whl/torch-2.8.0+cu126.html
# !pip install networkx scikit-learn
# !pip install jetnet --no-cache-dir

# %%
# Install JetNet without cache to ensure clean install

# Restart runtime after installation (in Colab: Runtime -> Restart Runtime)
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# Alternative: Use energyflow package if JetNet has compatibility issues
# !pip install energyflow
import math
import numpy as np
import matplotlib.pyplot as plt
from jetnet.datasets import JetNet
USE_JETNET = True
print("Using JetNet dataset")

import networkx as nx
from sklearn.neighbors import kneighbors_graph
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch_geometric.data import Data, Batch
from torch_geometric.nn import ChebConv, global_mean_pool, global_max_pool, global_add_pool  # Added global_add_pool
from torch_geometric.loader import DataLoader as GeometricDataLoader

from scipy.stats import wasserstein_distance, ks_2samp

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# --- 1. Data Loading and Preprocessing ---

def load_jetnet_data():
    """Load JetNet dataset with fallback options"""
    global USE_JETNET

    if USE_JETNET is None:
        raise ImportError("No suitable dataset package available")

    if USE_JETNET:
        # Load JetNet data
        particle_data, jet_data = JetNet.getData(
            jet_type=['g', 'q', 't'],
            data_dir="jetnet_data",
            particle_features=['etarel', 'phirel', 'ptrel', 'mask'],
            jet_features=['pt', 'eta', 'mass', 'num_particles'],
            num_particles=150,
            split='train',
            download=True
        )

        print("Particle shape:", particle_data.shape)
        print("Jet shape:", jet_data.shape)
        print(f"Total number of jets in dataset: {len(particle_data)}")

        return particle_data, jet_data

def get_hits_from_jetnet(jet_particles, jet_info):
    """Extract hits from JetNet particle data"""
    # Get valid particles (mask == 1)
    valid_mask = jet_particles[:, 3] == 1
    valid_particles = jet_particles[valid_mask]

    if len(valid_particles) == 0:
        return None

    # Sort by descending pt_rel
    sorted_idx = np.argsort(-valid_particles[:, 2])
    valid_particles = valid_particles[sorted_idx]

    # Extract features
    eta = valid_particles[:, 0]  # etarel
    phi = valid_particles[:, 1]  # phirel
    pt = valid_particles[:, 2]   # ptrel

    # Create hits array: [eta, phi, pt]
    hits = np.column_stack((eta, phi, pt))

    return hits

def make_graph(hits):
    """Create graph from hits using k-nearest neighbors"""
    if len(hits) < 4:  # Need at least 4 points for k=4
        # Use smaller k for sparse jets
        k = min(len(hits) - 1, 2)
        if k <= 0:
            return None, hits, None
    else:
        k = 4

    coords = hits[:, :2]  # eta, phi coordinates
    adj_matrix = kneighbors_graph(coords, n_neighbors=k, mode='connectivity', include_self=False)
    G = nx.from_scipy_sparse_array(adj_matrix)
    return G, hits, adj_matrix



def collect_graph_and_targets(particle_data, jet_data, max_jets=3200):
    """Collect graph data and targets for training"""
    graph_data = []
    target_particles = []
    original_jets = []
    failed_count = 0

    n_jets = min(len(particle_data), max_jets)
    print(f"Collecting data for {n_jets} jets...")

    for i in range(n_jets):
        if i % 100 == 0:
            print(f"Processing jet {i}/{n_jets}...")

        try:
            jet_particles = particle_data[i]
            jet_info = jet_data[i]

            hits = get_hits_from_jetnet(jet_particles, jet_info)
            if hits is None or len(hits) == 0:
                failed_count += 1
                continue

            G, hits, adj_matrix = make_graph(hits)
            if G is None or adj_matrix is None:
                failed_count += 1
                continue

            x = torch.tensor(hits, dtype=torch.float)
            edge_index = torch.tensor(np.array(np.nonzero(adj_matrix)), dtype=torch.long)

            data = Data(x=x, edge_index=edge_index)
            graph_data.append(data)

            # Sort target particles by descending pt_rel and pad
            valid_mask = jet_particles[:, 3] == 1
            valid_particles = jet_particles[valid_mask]
            if len(valid_particles) > 0:
                sorted_idx = np.argsort(-valid_particles[:, 2])
                sorted_valid = valid_particles[sorted_idx]
            else:
                sorted_valid = np.empty((0, 4))
            padded = np.zeros((150, 4))
            padded[:len(sorted_valid)] = sorted_valid
            padded[:len(sorted_valid), 3] = 1  # set mask
            target_particles.append(torch.tensor(padded, dtype=torch.float))

            original_jets.append((jet_particles, jet_info))

        except Exception as e:
            print(f"Error processing jet {i}: {e}")
            failed_count += 1
            continue

    print(f"\nCollection complete!")
    print(f"Successfully collected: {len(graph_data)} jets")
    print(f"Failed: {failed_count} jets")

    return graph_data, target_particles, original_jets

# --- 2. Graph Neural Network Model ---

class SimpleChebNet(nn.Module):
    def __init__(self, in_dim=3, hidden_dim=64, K=4, out_dim=32):
        super().__init__()
        self.conv1 = ChebConv(in_dim, hidden_dim, K)
        self.conv2 = ChebConv(hidden_dim, hidden_dim, K)
        self.conv3 = ChebConv(hidden_dim, hidden_dim, K)  # Added for depth
        self.conv4 = ChebConv(hidden_dim, out_dim, K)     # Added for depth
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.bn2 = nn.BatchNorm1d(hidden_dim)
        self.bn3 = nn.BatchNorm1d(hidden_dim)  # Added

    def forward(self, x, edge_index, batch=None):
        x = self.conv1(x, edge_index)
        x = self.bn1(F.leaky_relu(x))
        x = self.conv2(x, edge_index)
        x = self.bn2(F.leaky_relu(x))
        x = self.conv3(x, edge_index)
        x = self.bn3(F.leaky_relu(x))
        x = self.conv4(x, edge_index)
        x = F.normalize(x, p=2, dim=1)  # L2 normalize embeddings

        # MODIFIED: Concat mean, max, min, sum pooling
        if batch is None:
            mean_p = x.mean(dim=0)
            max_p = x.max(dim=0)[0]
            min_p = -(-x).max(dim=0)[0]  # Equivalent to min
            sum_p = x.sum(dim=0)
            pooled = torch.cat([mean_p, max_p, min_p, sum_p], dim=-1)
        else:
            mean_p = global_mean_pool(x, batch)
            max_p = global_max_pool(x, batch)
            min_p = -global_max_pool(-x, batch)
            sum_p = global_add_pool(x, batch)
            pooled = torch.cat([mean_p, max_p, min_p, sum_p], dim=1)

        return pooled  # Now dim=128 (out_dim*4)

# --- 3. Diffusion Model with Batching ---

class SimpleDiffusionMLP(nn.Module):
    def __init__(self, emb_dim, hidden_dim=512):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(emb_dim+1, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, emb_dim)
        )

    def forward(self, x, t):
        # x: [batch, emb_dim], t: [batch, 1]
        xt = torch.cat([x, t], dim=1)
        return self.net(xt)

class DiffusionDataset(Dataset):
    def __init__(self, embeddings):
        self.embeddings = torch.tensor(embeddings, dtype=torch.float32)

    def __len__(self):
        return len(self.embeddings)

    def __getitem__(self, idx):
        return self.embeddings[idx]

def beta(t, beta_0=1e-4, beta_1=0.02):
    """Linear beta schedule"""
    return beta_0 + t * (beta_1 - beta_0)

def alpha_bar(t, beta_0=1e-4, beta_1=0.02):
    return torch.exp(-(beta_0 * t + 0.5 * (beta_1 - beta_0) * t * t))

def train_diffusion_model_batched(embeddings, n_steps=1000, epochs=200, batch_size=8):
    """Train diffusion model on embeddings with proper batching"""
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    emb_dim = embeddings.shape[1]
    model = SimpleDiffusionMLP(emb_dim).to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-4)

    # Create dataset and dataloader
    dataset = DiffusionDataset(embeddings)
    dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=0,
        pin_memory=True if device.type == 'cuda' else False
    )

    print(f"Training diffusion model with {len(embeddings)} embeddings...")
    print(f"Batch size: {batch_size}, Batches per epoch: {len(dataloader)}")

    model.train()

    for epoch in range(epochs):
        epoch_loss = 0.0
        num_batches = 0

        for batch_idx, batch in enumerate(dataloader):
            batch = batch.to(device, non_blocking=True)
            batch_size_actual = batch.size(0)

            # Random time steps for each sample in batch
            t = torch.rand((batch_size_actual, 1), device=device)
            sqrt_alpha_bar_t = torch.sqrt(alpha_bar(t)) #how much noise to mix with original signal-> signal retention coeffecient
            sqrt_1_minus_alpha_bar_t = torch.sqrt(1 - alpha_bar(t)) #noise coefficient

            # Add noise
            noise = torch.randn_like(batch)
            noisy_data = batch * sqrt_alpha_bar_t + noise * sqrt_1_minus_alpha_bar_t  # linear noise schedule

            # Predict noise
            pred_noise = model(noisy_data, t)
            loss = ((pred_noise - noise)**2).mean()

            # Backpropagation
            optimizer.zero_grad()
            loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            optimizer.step()

            epoch_loss += loss.item()
            num_batches += 1

            # Clear cache periodically
            if batch_idx % 10 == 0:
                torch.cuda.empty_cache()

        avg_loss = epoch_loss / num_batches
        if epoch % 10 == 0:
            print(f"Diffusion Epoch {epoch}/{epochs}, Loss: {avg_loss:.4f}")

        # Clear cache at end of epoch
        torch.cuda.empty_cache()

    return model

def sample_diffusion_model_batched(model, emb_dim, n_samples=10, n_steps=200, batch_size=8):  # Increased n_steps
    """Sample new embeddings from trained diffusion model with batching using deterministic DDIM"""
    device = next(model.parameters()).device
    model.eval()

    all_samples = []

    with torch.no_grad():
        # Process samples in batches
        for i in range(0, n_samples, batch_size):
            current_batch_size = min(batch_size, n_samples - i)
            x = torch.randn((current_batch_size, emb_dim), device=device)

            # DDIM sampling loop (deterministic, eta=0, approximates probability flow ODE)
            for step in range(n_steps, 0, -1):
                t_value = step / n_steps
                s_value = (step - 1) / n_steps
                t = torch.full((current_batch_size, 1), t_value, device=device)
                alpha_t = alpha_bar(t)
                alpha_s = alpha_bar(torch.full((current_batch_size, 1), s_value, device=device))
                noise_pred = model(x, t)

                # DDIM formula (deterministic)
                sqrt_alpha_t = torch.sqrt(alpha_t)
                sqrt_alpha_s = torch.sqrt(alpha_s)
                sqrt_one_minus_alpha_t = torch.sqrt(1 - alpha_t)
                sqrt_one_minus_alpha_s = torch.sqrt(1 - alpha_s)

                pred_x0 = (x - sqrt_one_minus_alpha_t * noise_pred) / sqrt_alpha_t
                x = sqrt_alpha_s * pred_x0 + sqrt_one_minus_alpha_s * noise_pred  # No sigma/noise term for deterministic

            all_samples.append(x.cpu().numpy())

    # Concatenate all batches
    return np.concatenate(all_samples, axis=0)

# --- 4. Enhanced Decoder Model for Particle Generation ---

class JetGraphDataset(Dataset):
    def __init__(self, graph_data, target_particles):
        self.graph_data = graph_data
        self.target_particles = target_particles

    def __len__(self):
        return len(self.graph_data)

    def __getitem__(self, idx):
        return self.graph_data[idx], self.target_particles[idx]

def collate_fn(batch):
    graphs = [b[0] for b in batch]
    targets = [b[1] for b in batch]
    batched_graph = Batch.from_data_list(graphs)
    batched_targets = torch.stack(targets)
    return batched_graph, batched_targets

class ParticleDecoder(nn.Module):
    def __init__(self, emb_dim, max_particles=150, particle_dim=4, hidden_dims=[512, 1024]):  # MODIFIED: Increased hidden dims for more capacity
        super().__init__()
        self.max_particles = max_particles
        self.particle_dim = particle_dim
        self.output_size = max_particles * particle_dim

        # Build progressive layers
        layers = []
        current_dim = emb_dim

        # Input projection
        layers.extend([
            nn.Linear(current_dim, hidden_dims[0]),
            nn.BatchNorm1d(hidden_dims[0]),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.1)
        ])
        current_dim = hidden_dims[0]

        # Expansion layer
        layers.extend([
            nn.Linear(current_dim, hidden_dims[1]),
            nn.BatchNorm1d(hidden_dims[1]),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.1)
        ])
        current_dim = hidden_dims[1]

        # Output layer
        layers.extend([
            nn.Linear(current_dim, self.output_size)
        ])

        self.main_net = nn.Sequential(*layers)

        # Residual connection
        self.residual_projection = nn.Sequential(
            nn.Linear(emb_dim, 128),
            nn.LeakyReLU(0.2),
            nn.Linear(128, self.output_size)
        )

        # Initialize weights
        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            nn.init.xavier_uniform_(module.weight)
            if module.bias is not None:
                nn.init.constant_(module.bias, 0)
        elif isinstance(module, nn.BatchNorm1d):
            nn.init.constant_(module.weight, 1)
            nn.init.constant_(module.bias, 0)

    def forward(self, z):
        # Main path
        main_out = self.main_net(z)

        # Residual path
        residual_out = self.residual_projection(z)

        # Combine
        combined = main_out + 0.1 * residual_out

        # Reshape to particle format
        output = combined.view(-1, self.max_particles, self.particle_dim)

        # Apply appropriate activations
        # etarel, phirel can be negative, ptrel should be positive, mask should be 0-1
        eta = torch.tanh(output[:, :, 0]) * 0.8  # Scale to data range ~(-0.8, 0.8)
        phi = torch.tanh(output[:, :, 1]) * 0.8  # Scale to data range ~(-0.8, 0.8)

        # --- NEW p_T ACTIVATION ---
        # Map to [0, 0.5], which better covers your data's p_T range
        pt = torch.sigmoid(output[:, :, 2]) * 0.5   # Removed *0.1 for proper scaling

        # Better mask activation with temperature
        mask_logits = output[:, :, 3]
        mask = torch.sigmoid(mask_logits * 2.0)  # Higher temperature for sharper decisions

        output = torch.stack([eta, phi, pt, mask], dim=2)
        return output

def masked_wasserstein_loss(pred_particles, target_particles):
    """
    Calculates the 1-Wasserstein loss (approximated by L1 on sorted vectors)
    for eta, phi, and pt, using masks.

    This function is IMMUNE to padded [0,0,0] values.
    """
    # Get features and masks
    pred_eta = pred_particles[:, :, 0]
    pred_phi = pred_particles[:, :, 1]
    pred_pt = pred_particles[:, :, 2]
    pred_mask = pred_particles[:, :, 3] # Soft mask [B, 150]

    target_eta = target_particles[:, :, 0]
    target_phi = target_particles[:, :, 1]
    target_pt = target_particles[:, :, 2]
    target_mask = (target_particles[:, :, 3] > 0.5).float() # Binary mask [B, 150]

    # --- This is the key insight ---
    # We multiply the features by their masks.
    # All padded particles (where target_mask=0) will have their features set to 0.
    # All "fake" predicted particles (where pred_mask is low) will have features near 0.

    pred_eta_masked = pred_eta * pred_mask
    pred_phi_masked = pred_phi * pred_mask
    pred_pt_masked = pred_pt * pred_mask

    target_eta_masked = target_eta * target_mask
    target_phi_masked = target_phi * target_mask
    target_pt_masked = target_pt * target_mask

    # Sort the masked features along the particle dimension (dim=1)
    # All the 0-valued padded particles will be sorted to one end of the list.
    pred_eta_sorted, _ = torch.sort(pred_eta_masked, dim=1)
    pred_phi_sorted, _ = torch.sort(pred_phi_masked, dim=1)
    pred_pt_sorted, _ = torch.sort(pred_pt_masked, dim=1)

    target_eta_sorted, _ = torch.sort(target_eta_masked, dim=1)
    target_phi_sorted, _ = torch.sort(target_phi_masked, dim=1)
    target_pt_sorted, _ = torch.sort(target_pt_masked, dim=1)

    # Calculate L1 loss (which approximates 1-Wasserstein)
    # The loss for the 0-padded particles will be 0-vs-0, which is 0.
    # The loss is ONLY driven by the non-zero (real) particles!
    loss_fn = nn.L1Loss()
    w_loss_eta = loss_fn(pred_eta_sorted, target_eta_sorted)
    w_loss_phi = loss_fn(pred_phi_sorted, target_phi_sorted)
    w_loss_pt = loss_fn(pred_pt_sorted, target_pt_sorted)

    return w_loss_eta + w_loss_phi + w_loss_pt

def train_autoencoder(gnn, decoder, graph_data, target_particles, epochs=300, batch_size=8):  # Increased epochs
    """Train GNN and decoder jointly as autoencoder"""
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Training autoencoder on device: {device}")

    # Dataset and loader
    dataset = JetGraphDataset(graph_data, target_particles)
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn, num_workers=0, pin_memory=True if device.type == 'cuda' else False)

    # Optimizer and scheduler
    optimizer = optim.AdamW(list(gnn.parameters()) + list(decoder.parameters()), lr=0.001, weight_decay=1e-5)
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs//4, eta_min=1e-6)

    # Loss functions
    mse_criterion = nn.MSELoss()
    bce_criterion = nn.BCELoss()

    print(f"Training autoencoder with {len(dataset)} samples, batch size {batch_size}")
    print(f"Total parameters: {sum(p.numel() for p in gnn.parameters()) + sum(p.numel() for p in decoder.parameters()):,}")

    gnn.train()
    decoder.train()
    best_loss = float('inf')
    patience_counter = 0

    for epoch in range(epochs):
        epoch_loss = 0.0
        num_batches = 0

        for batch_idx, (batch_graph, batch_target) in enumerate(loader):
            batch_graph = batch_graph.to(device)
            batch_target = batch_target.to(device)

            # Forward through GNN and pool (MODIFIED pooling is handled in GNN forward)
            pooled = gnn(batch_graph.x, batch_graph.edge_index, batch_graph.batch)

            # Decode
            pred = decoder(pooled)

            # Losses (increased eta and phi loss weights to improve their reconstructions and EMD)
            particle_loss = masked_wasserstein_loss(pred, batch_target)
            mask_loss = bce_criterion(pred[:, :, 3], batch_target[:, :, 3])
            target_num = torch.sum(batch_target[:, :, 3], dim=1)
            pred_num = torch.sum(pred[:, :, 3], dim=1)
            count_loss = nn.MSELoss()(pred_num, target_num)
            loss = particle_loss * 100.0 + mask_loss * 2.0 + count_loss * 0.01
            if(epoch%10==0):
              print(f"Particle loss: {100*particle_loss:.4f}, Mask loss: {2*mask_loss:.4f}, Count loss: {0.001*count_loss:.4f}")


            # Backward
            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(list(gnn.parameters()) + list(decoder.parameters()), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()
            num_batches += 1

            if batch_idx % 5 == 0:
                torch.cuda.empty_cache()

        avg_loss = epoch_loss / num_batches

        old_lr = optimizer.param_groups[0]['lr']
        scheduler.step()
        new_lr = optimizer.param_groups[0]['lr']
        if old_lr != new_lr:
            print(f"  Learning rate reduced from {old_lr:.8f} to {new_lr:.8f}")

        # Early stopping
        if avg_loss < best_loss:
            best_loss = avg_loss
            patience_counter = 0
        else:
            patience_counter += 1

        if epoch % 10 == 0:
            print(f"Autoencoder Epoch {epoch}/{epochs}")
            print(f"  Loss: {avg_loss:.6f}")
            print(f"  LR: {optimizer.param_groups[0]['lr']:.8f}")
            print(f"  Best Loss: {best_loss:.6f}, Patience: {patience_counter}")

        if patience_counter >= 15:
            print(f"Early stopping at epoch {epoch}")
            break

        torch.cuda.empty_cache()

    return gnn, decoder

# --- 5. Visualization Functions ---

def visualize_particle_jets(particle_data_list, titles, n_cols=2):
    """Visualize jets as scatter plots using particle data"""
    n_jets = len(particle_data_list)
    n_rows = (n_jets + n_cols - 1) // n_cols

    plt.style.use('default')
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(12 * n_cols, 6 * n_rows))
    fig.patch.set_facecolor('white')

    # Handle single row case
    if n_rows == 1:
        axes = axes.reshape(1, -1) if n_cols > 1 else [axes]
    elif n_cols == 1:
        axes = axes.reshape(-1, 1)

    for i, (particles, title) in enumerate(zip(particle_data_list, titles)):
        row = i // n_cols
        col = i % n_cols
        ax = axes[row, col] if n_rows > 1 else axes[col]

        # Get valid particles
        valid_mask = particles[:, 3] > 0.5  # Use threshold for mask
        if valid_mask.sum() == 0:
            ax.text(0.5, 0.5, 'No valid particles', ha='center', va='center', transform=ax.transAxes)
            ax.set_title(title, fontsize=12, fontweight='bold')
            continue

        valid_particles = particles[valid_mask]
        eta = valid_particles[:, 0]
        phi = valid_particles[:, 1]
        pt = valid_particles[:, 2]

        # Create scatter plot
        scatter = ax.scatter(eta, phi, c=pt, s=50, cmap='viridis', alpha=0.7)

        ax.set_title(f"{title}\nParticles: {len(valid_particles)}", fontsize=12, fontweight='bold')
        ax.set_xlabel('η_rel', fontsize=10)
        ax.set_ylabel('φ_rel', fontsize=10)
        ax.grid(True, alpha=0.3)

        # Add colorbar
        cbar = plt.colorbar(scatter, ax=ax, fraction=0.046, pad=0.04)
        cbar.set_label('p_T', fontsize=10)

        # Set reasonable axis limits
        ax.set_xlim(-0.8, 0.8)
        ax.set_ylim(-0.8, 0.8)

    # Hide unused subplots
    for i in range(n_jets, n_rows * n_cols):
        row = i // n_cols
        col = i % n_cols
        ax = axes[row, col] if n_rows > 1 else axes[col]
        ax.set_visible(False)

    plt.tight_layout()
    plt.show()

def calculate_kl_divergence(real_data, generated_data, n_bins=100):
    """
    KL divergence following the paper's methodology exactly
    """
    # Remove invalid values
    real_data = real_data[np.isfinite(real_data)]
    generated_data = generated_data[np.isfinite(generated_data)]

    if len(real_data) == 0 or len(generated_data) == 0:
        return float('inf')

    # PAPER'S METHOD: Equiprobable quantile binning from target distribution
    min_val, max_val = real_data.min(), real_data.max()

    generated_data_clipped = np.clip(generated_data, min_val, max_val)

    bin_edges = np.quantile(real_data, np.linspace(0, 1, n_bins + 1))
    bin_edges[0] -= 1e-10
    bin_edges[-1] += 1e-10

    # Calculate histograms
    real_hist, _ = np.histogram(real_data, bins=bin_edges)
    gen_hist, _ = np.histogram(generated_data_clipped, bins=bin_edges)

    # Convert to probabilities
    real_prob = real_hist / real_hist.sum()
    gen_prob = gen_hist / gen_hist.sum()

    # Add epsilon and calculate KL
    epsilon = 1e-10
    real_prob = np.maximum(real_prob, epsilon)
    gen_prob = np.maximum(gen_prob, epsilon)

    kl_div = np.sum(real_prob * np.log(real_prob / gen_prob))
    return kl_div

def compare_particle_reconstruction(original_particles, reconstructed_particles, idx):
    """Compare original and reconstructed particle data"""
    plt.style.use('default')
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))
    fig.patch.set_facecolor('white')

    # Original particles
    orig_valid = original_particles[:, 3] == 1
    if orig_valid.sum() > 0:
        orig_valid_particles = original_particles[orig_valid]
        scatter1 = ax1.scatter(orig_valid_particles[:, 0], orig_valid_particles[:, 1],
                             c=orig_valid_particles[:, 2], s=50, cmap='viridis', alpha=0.7)
        ax1.set_title(f'Original Jet {idx+1} ({orig_valid.sum()} particles)')
        ax1.set_xlabel('η_rel')
        ax1.set_ylabel('φ_rel')
        ax1.set_xlim(-0.8, 0.8)
        ax1.set_ylim(-0.8, 0.8)
        ax1.grid(True, alpha=0.3)
        plt.colorbar(scatter1, ax=ax1, label='p_T')

    # Reconstructed particles
    recon_valid = reconstructed_particles[:, 3] > 0.5
    if recon_valid.sum() > 0:
        recon_valid_particles = reconstructed_particles[recon_valid]
        scatter2 = ax2.scatter(recon_valid_particles[:, 0], recon_valid_particles[:, 1],
                             c=recon_valid_particles[:, 2], s=50, cmap='viridis', alpha=0.7)
        ax2.set_title(f'Reconstructed Jet {idx+1} ({recon_valid.sum()} particles)')
        ax2.set_xlabel('η_rel')
        ax2.set_ylabel('φ_rel')
        ax2.set_xlim(-0.8, 0.8)
        ax2.set_ylim(-0.8, 0.8)
        ax2.grid(True, alpha=0.3)
        plt.colorbar(scatter2, ax=ax2, label='p_T')

    # Feature distributions
    if orig_valid.sum() > 0 and recon_valid.sum() > 0:
        orig_valid_particles = original_particles[orig_valid]
        recon_valid_particles = reconstructed_particles[recon_valid]
        # η distribution
        ax3.hist(orig_valid_particles[:, 0], bins=100, alpha=0.5, label='Original', density=True)
        ax3.hist(recon_valid_particles[:, 0], bins=100, alpha=0.5, label='Reconstructed', density=True)
        ax3.set_xlabel('η_rel')
        ax3.set_ylabel('Density')
        ax3.set_title('η Distribution')
        ax3.legend()
        ax3.grid(True, alpha=0.3)

        # p_T distribution
        ax4.hist(orig_valid_particles[:, 2], bins=100, alpha=0.5, label='Original', density=True)
        ax4.hist(recon_valid_particles[:, 2], bins=100, alpha=0.5, label='Reconstructed', density=True)
        ax4.set_xlabel('p_T')
        ax4.set_ylabel('Density')
        ax4.set_title('p_T Distribution')
        ax4.legend()
        ax4.grid(True, alpha=0.3)
        ws_eta = wasserstein_distance(orig_valid_particles[:, 0], recon_valid_particles[:, 0])
        ws_phi = wasserstein_distance(orig_valid_particles[:, 1], recon_valid_particles[:, 1])
        ws_pt = wasserstein_distance(orig_valid_particles[:, 2], recon_valid_particles[:, 2])
        kl_eta = calculate_kl_divergence(orig_valid_particles[:, 0], recon_valid_particles[:, 0])
        kl_phi = calculate_kl_divergence(orig_valid_particles[:, 1], recon_valid_particles[:, 1])
        kl_pt = calculate_kl_divergence(orig_valid_particles[:, 2], recon_valid_particles[:, 2])


        print(f"Jet {idx+1} Metrics:")
        print(f"Wasserstein η: {ws_eta:.4f}, φ: {ws_phi:.4f}, p_T: {ws_pt:.4f}")
        print(f"KL Divergence η: {kl_eta:.4f}, φ: {kl_phi:.4f}, p_T: {kl_pt:.4f}")

    plt.tight_layout()
    plt.show()

    # Print statistics
    print(f"Jet {idx+1} Statistics:")
    print(f"Original particles: {orig_valid.sum()}")
    print(f"Reconstructed particles: {recon_valid.sum()}")
    if orig_valid.sum() > 0:
        print(f"Original η range: [{orig_valid_particles[:, 0].min():.3f}, {orig_valid_particles[:, 0].max():.3f}]")
        print(f"Original p_T range: [{orig_valid_particles[:, 2].min():.3f}, {orig_valid_particles[:, 2].max():.3f}]")
    if recon_valid.sum() > 0:
        print(f"Reconstructed η range: [{recon_valid_particles[:, 0].min():.3f}, {recon_valid_particles[:, 0].max():.3f}]")
        print(f"Reconstructed p_T range: [{recon_valid_particles[:, 2].min():.3f}, {recon_valid_particles[:, 2].max():.3f}]")
    print()

# --- 6. Main Pipeline with JetNet Data ---

def main_pipeline_jetnet(batch_size=8):
    """Main pipeline using JetNet dataset"""

    # 1. Load JetNet data
    print("=== Loading JetNet data ===")
    particle_data, jet_data = load_jetnet_data()

    # 2. Collect graph data and targets
    print("\n=== Collecting graph data ===")
    graph_data, target_particles, original_jets = collect_graph_and_targets(particle_data, jet_data, max_jets=5000)

    if len(graph_data) == 0:
        print("No jets were successfully collected!")
        return None

    # 3. Initialize and train autoencoder (GNN + decoder)
    print("\n=== Training autoencoder ===")
    gnn = SimpleChebNet(in_dim=3, hidden_dim=64, K=4, out_dim=32).to(device)  # out_dim=32, but pooled=128 after concat
    decoder = ParticleDecoder(emb_dim=128).to(device)  # MODIFIED: emb_dim=128 to match expanded pooling
    gnn, decoder = train_autoencoder(gnn, decoder, graph_data, target_particles, epochs=300, batch_size=batch_size)

    # 4. Extract pooled embeddings using trained GNN
    print("\n=== Extracting pooled embeddings ===")
    gnn.eval()
    all_pooled_embeddings = []
    for data in graph_data:
        data = data.to(device)
        with torch.no_grad():
            pooled = gnn(data.x, data.edge_index).cpu().numpy()  # MODIFIED: No batch, but forward handles it
        all_pooled_embeddings.append(pooled)
    all_pooled_embeddings = np.stack(all_pooled_embeddings)

    # 5. Train diffusion model
    print(f"\n=== Training diffusion model (batch_size={batch_size}) ===")
    diff_model = train_diffusion_model_batched(
        all_pooled_embeddings, epochs=200, batch_size=batch_size
    )

    # 6. Generate new samples
    print("\n=== Generating new samples ===")
    n_samples = 8
    new_embeddings = sample_diffusion_model_batched(
        diff_model, emb_dim=all_pooled_embeddings.shape[1],
        n_samples=n_samples, batch_size=batch_size
    )

    decoder.eval()
    with torch.no_grad():
        # Generate particles from embeddings
        generated_particles = []
        for i in range(0, len(new_embeddings), batch_size):
            batch_embeddings = new_embeddings[i:i+batch_size]
            batch_embeddings_torch = torch.tensor(batch_embeddings, dtype=torch.float32).to(device)
            batch_particles = decoder(batch_embeddings_torch).cpu().numpy()
            generated_particles.append(batch_particles)

        generated_particles = np.concatenate(generated_particles, axis=0)

    # 7. Visualize generated jets
    print(f"\n=== Visualizing {n_samples} generated jets ===")
    titles = [f'Generated Jet {i+1}' for i in range(n_samples)]
    visualize_particle_jets(generated_particles, titles)

    # 8. Compare decoder reconstructions
    print("\n=== Particle decoder reconstruction comparison ===")
    n_compare = min(3, len(all_pooled_embeddings))
    comparison_embeddings = all_pooled_embeddings[:n_compare]

    with torch.no_grad():
        comparison_embeddings_torch = torch.tensor(comparison_embeddings, dtype=torch.float32).to(device)
        decoder_reconstructions = decoder(comparison_embeddings_torch).cpu().numpy()

    for i in range(n_compare):
        original_particles, _ = original_jets[i]
        decoder_reconstruction = decoder_reconstructions[i]
        compare_particle_reconstruction(original_particles, decoder_reconstruction, i)

    # Fixed metrics loop to n_compare
    ws_eta_list, ws_phi_list, ws_pt_list = [], [], []
    kl_eta_list, kl_phi_list, kl_pt_list = [], [], []

    for i in range(n_compare):
        original_particles, _ = original_jets[i]
        decoder_reconstruction = decoder_reconstructions[i]
        orig_valid = original_particles[:, 3] == 1
        recon_valid = decoder_reconstruction[:, 3] > 0.5

        if orig_valid.sum() > 0 and recon_valid.sum() > 0:
            orig_valid_particles = original_particles[orig_valid]
            recon_valid_particles = decoder_reconstruction[recon_valid]

            # Wasserstein
            ws_eta = wasserstein_distance(orig_valid_particles[:, 0], recon_valid_particles[:, 0])
            ws_phi = wasserstein_distance(orig_valid_particles[:, 1], recon_valid_particles[:, 1])
            ws_pt = wasserstein_distance(orig_valid_particles[:, 2], recon_valid_particles[:, 2])

            # KL
            kl_eta = calculate_kl_divergence(orig_valid_particles[:, 0], recon_valid_particles[:, 0])
            kl_phi = calculate_kl_divergence(orig_valid_particles[:, 1], recon_valid_particles[:, 1])
            kl_pt = calculate_kl_divergence(orig_valid_particles[:, 2], recon_valid_particles[:, 2])

            ws_eta_list.append(ws_eta)
            ws_phi_list.append(ws_phi)
            ws_pt_list.append(ws_pt)
            kl_eta_list.append(kl_eta)
            kl_phi_list.append(kl_phi)
            kl_pt_list.append(kl_pt)

    if ws_eta_list:
        avg_ws_eta = sum(ws_eta_list) / len(ws_eta_list)
        avg_ws_phi = sum(ws_phi_list) / len(ws_phi_list)
        avg_ws_pt = sum(ws_pt_list) / len(ws_pt_list)

        avg_kl_eta = sum(kl_eta_list) / len(kl_eta_list)
        avg_kl_phi = sum(kl_phi_list) / len(kl_phi_list)
        avg_kl_pt = sum(kl_pt_list) / len(kl_pt_list)

        print("\nComponent-wise Average Metrics (over comparisons):")
        print(f"Wasserstein - η: {avg_ws_eta:.4f}, φ: {avg_ws_phi:.4f}, p_T: {avg_ws_pt:.4f}")
        print(f"KL Divergence - η: {avg_kl_eta:.4f}, φ: {avg_kl_phi:.4f}, p_T: {avg_kl_pt:.4f}")

    # 9. Show random real jets
    print("\n=== Random real jets for comparison ===")
    n_compare = 3
    random_indices = np.random.choice(len(original_jets), n_compare, replace=False)
    random_jets = [original_jets[idx][0] for idx in random_indices]  # Extract particle data
    random_titles = [f'Random Real Jet (Index {idx})' for idx in random_indices]
    visualize_particle_jets(random_jets, random_titles)

    # 10. Print summary
    print(f"\n=== Summary ===")
    print(f"Total jets in dataset: {len(particle_data)}")
    print(f"Successfully processed: {len(all_pooled_embeddings)}")
    print(f"Processing success rate: {len(all_pooled_embeddings)/len(particle_data)*100:.1f}%")
    print(f"Embedding dimension: {all_pooled_embeddings.shape[1]}")
    print(f"Generated samples: {n_samples}")
    print(f"Max particles per jet: 150")
    print(f"Batch size used for training: {batch_size}")

    return {
        'embeddings': all_pooled_embeddings,
        'original_jets': original_jets,
        'diffusion_model': diff_model,
        'decoder': decoder,
        'generated_particles': generated_particles,
        'particle_data': particle_data,
        'jet_data': jet_data
    }

# --- 7. Additional Utility Functions ---

def plot_jetnet_sample_jets(particle_data, jet_data, jet_nums=[0, 1, 2]):
    """Plot sample jets from JetNet dataset for initial visualization"""
    for idx in jet_nums:
        jet_particles = particle_data[idx]
        jet_info = jet_data[idx]

        # Get valid particles
        valid = jet_particles[jet_particles[:, 3] == 1]

        if len(valid) == 0:
            print(f"Jet {idx} has no valid particles, skipping...")
            continue

        eta = valid[:, 0]
        phi = valid[:, 1]
        pt = valid[:, 2]
        energy = pt * jet_info[0]  # pt * jet_pt

        plt.figure(figsize=(10, 4))
        plt.subplot(1, 2, 1)
        scatter = plt.scatter(eta, phi, c=energy, s=50, cmap='viridis', alpha=0.7)
        plt.title(f"Jet {idx}\npT: {jet_info[0]:.2f} GeV, eta: {jet_info[1]:.2f}")
        plt.xlabel("eta_rel")
        plt.ylabel("phi_rel")
        plt.colorbar(scatter, label="Energy")
        plt.grid(True, alpha=0.3)

        # Feature distribution plot
        plt.subplot(1, 2, 2)
        plt.hist(pt, bins=20, alpha=0.7, label='p_T distribution')
        plt.xlabel('p_T')
        plt.ylabel('Count')
        plt.title(f'p_T Distribution (Jet {idx})')
        plt.legend()
        plt.grid(True, alpha=0.3)

        plt.tight_layout()
        plt.savefig(f"jetnet_jet_{idx}.png")
        plt.show()

        print(f"Jet {idx} Stats:")
        print("Particles:", len(valid))
        print("Jet info:", jet_info)
        print("eta mean:", np.mean(eta))
        print("phi mean:", np.mean(phi))
        print("pt mean:", np.mean(pt))
        print()

def analyze_jetnet_dataset(particle_data, jet_data):
    """Analyze the JetNet dataset structure and statistics"""
    print("=== JetNet Dataset Analysis ===")
    print(f"Particle data shape: {particle_data.shape}")
    print(f"Jet data shape: {jet_data.shape}")

    # Count valid particles per jet
    valid_particles_per_jet = []
    for i in range(len(particle_data)):
        valid_count = (particle_data[i][:, 3] == 1).sum()
        valid_particles_per_jet.append(valid_count)

    valid_particles_per_jet = np.array(valid_particles_per_jet)

    print(f"\nParticle Statistics:")
    print(f"Average particles per jet: {valid_particles_per_jet.mean():.2f}")
    print(f"Std particles per jet: {valid_particles_per_jet.std():.2f}")
    print(f"Min particles per jet: {valid_particles_per_jet.min()}")
    print(f"Max particles per jet: {valid_particles_per_jet.max()}")

    # Jet feature statistics
    print(f"\nJet Statistics:")
    print(f"Jet pT range: [{jet_data[:, 0].min():.2f}, {jet_data[:, 0].max():.2f}] GeV")
    print(f"Jet eta range: [{jet_data[:, 1].min():.2f}, {jet_data[:, 1].max():.2f}]")
    print(f"Jet mass range: [{jet_data[:, 2].min():.2f}, {jet_data[:, 2].max():.2f}] GeV")
    print(f"Reported num_particles range: [{jet_data[:, 3].min():.0f}, {jet_data[:, 3].max():.0f}]")

    # Plot distributions
    plt.figure(figsize=(15, 10))

    plt.subplot(2, 3, 1)
    plt.hist(valid_particles_per_jet, bins=50, alpha=0.7)
    plt.xlabel('Number of particles')
    plt.ylabel('Count')
    plt.title('Particles per jet distribution')
    plt.grid(True, alpha=0.3)

    plt.subplot(2, 3, 2)
    plt.hist(jet_data[:, 0], bins=50, alpha=0.7)
    plt.xlabel('Jet pT (GeV)')
    plt.ylabel('Count')
    plt.title('Jet pT distribution')
    plt.grid(True, alpha=0.3)

    plt.subplot(2, 3, 3)
    plt.hist(jet_data[:, 1], bins=50, alpha=0.7)
    plt.xlabel('Jet eta')
    plt.ylabel('Count')
    plt.title('Jet eta distribution')
    plt.grid(True, alpha=0.3)

    plt.subplot(2, 3, 4)
    plt.hist(jet_data[:, 2], bins=50, alpha=0.7)
    plt.xlabel('Jet mass (GeV)')
    plt.ylabel('Count')
    plt.title('Jet mass distribution')
    plt.grid(True, alpha=0.3)

    # Particle feature distributions (from first 1000 jets)
    all_valid_particles = []
    for i in range(min(1000, len(particle_data))):
        valid_mask = particle_data[i][:, 3] == 1
        if valid_mask.sum() > 0:
            all_valid_particles.append(particle_data[i][valid_mask])

    if all_valid_particles:
        all_valid_particles = np.concatenate(all_valid_particles, axis=0)

        plt.subplot(2, 3, 5)
        plt.hist(all_valid_particles[:, 0], bins=50, alpha=0.7)
        plt.xlabel('eta_rel')
        plt.ylabel('Count')
        plt.title('Particle eta_rel distribution')
        plt.grid(True, alpha=0.3)

        plt.subplot(2, 3, 6)
        plt.hist(all_valid_particles[:, 2], bins=50, alpha=0.7)
        plt.xlabel('pt_rel')
        plt.ylabel('Count')
        plt.title('Particle pt_rel distribution')
        plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# --- 8. Run the pipeline ---

if __name__ == "__main__":
    # Set batch size for training
    BATCH_SIZE = 8

    # First, let's analyze the dataset
    print("Loading JetNet data for analysis...")
    particle_data, jet_data = load_jetnet_data()

    # Analyze dataset
    # analyze_jetnet_dataset(particle_data, jet_data)

    # Show some sample jets
    print("\n=== Sample JetNet jets ===")
    plot_jetnet_sample_jets(particle_data, jet_data, [0, 1, 2])

    # Run the complete pipeline
    print("\n=== Running complete JetNet pipeline ===")
    results = main_pipeline_jetnet(batch_size=BATCH_SIZE)

    if results is not None:
        # Optional: Save results
        # np.save('jetnet_embeddings.npy', results['embeddings'])
        # np.save('jetnet_generated_particles.npy', results['generated_particles'])
        # torch.save(results['diffusion_model'].state_dict(), 'jetnet_diffusion_model.pth')
        # torch.save(results['decoder'].state_dict(), 'jetnet_decoder_model.pth')

        print("\nJetNet pipeline completed successfully!")

        # Additional analysis of generated jets
        print("\n=== Generated Jet Analysis ===")
        generated_particles = results['generated_particles']

        # Count valid particles in generated jets
        generated_valid_counts = []
        for i in range(len(generated_particles)):
            valid_count = (generated_particles[i][:, 3] > 0.5).sum()
            generated_valid_counts.append(valid_count)

        generated_valid_counts = np.array(generated_valid_counts)

        print(f"Generated jets - Average particles: {generated_valid_counts.mean():.2f}")
        print(f"Generated jets - Std particles: {generated_valid_counts.std():.2f}")
        print(f"Generated jets - Range: [{generated_valid_counts.min()}, {generated_valid_counts.max()}]")

        # Compare with original dataset statistics
        original_valid_counts = []
        for jet_particles, _ in results['original_jets'][:len(generated_particles)]:
            valid_count = (jet_particles[:, 3] == 1).sum()
            original_valid_counts.append(valid_count)

        original_valid_counts = np.array(original_valid_counts)

        print(f"Original jets - Average particles: {original_valid_counts.mean():.2f}")
        print(f"Original jets - Std particles: {original_valid_counts.std():.2f}")
        print(f"Original jets - Range: [{original_valid_counts.min()}, {original_valid_counts.max()}]")

    else:
        print("\nPipeline failed - no jets were successfully processed.")
# Out:
# Using JetNet dataset
# Using device: cuda
# Loading JetNet data for analysis...
# Particle shape: (368113, 150, 4)
# Jet shape: (368113, 4)
# Total number of jets in dataset: 368113
#
# === Sample JetNet jets ===
# Jet 0 Stats:
# Particles: 70
# Jet info: [ 9.71209839e+02 -6.02245331e-02  1.08700569e+02  7.00000000e+01]
# eta mean: -0.066833936
# phi mean: 0.03076208
# pt mean: 0.014323129
# Jet 1 Stats:
# Particles: 72
# Jet info: [9.44443481e+02 3.21850777e-01 1.24882523e+02 7.20000000e+01]
# eta mean: 0.03138647
# phi mean: 0.028939048
# pt mean: 0.013899596
# Streaming output truncated to the last 5000 lines.
# Particle loss: 1.6013, Mask loss: 0.0772, Count loss: 0.0079
# Particle loss: 1.1098, Mask loss: 0.0609, Count loss: 0.0034
# Particle loss: 1.4474, Mask loss: 0.0602, Count loss: 0.0027
# Particle loss: 2.0358, Mask loss: 0.0716, Count loss: 0.0011
# Particle loss: 1.8275, Mask loss: 0.0566, Count loss: 0.0009
# Particle loss: 1.3957, Mask loss: 0.0554, Count loss: 0.0014
# Particle loss: 1.8218, Mask loss: 0.0534, Count loss: 0.0013
# Particle loss: 1.7223, Mask loss: 0.0564, Count loss: 0.0010
# Particle loss: 1.6257, Mask loss: 0.0560, Count loss: 0.0010
# Particle loss: 1.3575, Mask loss: 0.0635, Count loss: 0.0022
# Particle loss: 1.1334, Mask loss: 0.0571, Count loss: 0.0023
# Particle loss: 1.8446, Mask loss: 0.0835, Count loss: 0.0089
# Particle loss: 1.2296, Mask loss: 0.0592, Count loss: 0.0006
# Particle loss: 1.5655, Mask loss: 0.0662, Count loss: 0.0015
# Particle loss: 1.2214, Mask loss: 0.0595, Count loss: 0.0017
# Particle loss: 1.9744, Mask loss: 0.0742, Count loss: 0.0019
# Particle loss: 1.5295, Mask loss: 0.0657, Count loss: 0.0032
# Particle loss: 1.7560, Mask loss: 0.0657, Count loss: 0.0016
# Particle loss: 1.5400, Mask loss: 0.0781, Count loss: 0.0055
# Particle loss: 1.4712, Mask loss: 0.0659, Count loss: 0.0015
# Particle loss: 1.3107, Mask loss: 0.0707, Count loss: 0.0059
# Particle loss: 1.6681, Mask loss: 0.0663, Count loss: 0.0046
# Particle loss: 1.3063, Mask loss: 0.0687, Count loss: 0.0013
# Particle loss: 1.7804, Mask loss: 0.0664, Count loss: 0.0021
# Particle loss: 1.4751, Mask loss: 0.0659, Count loss: 0.0021
# Particle loss: 1.3477, Mask loss: 0.0637, Count loss: 0.0036
# Particle loss: 1.2102, Mask loss: 0.0568, Count loss: 0.0010
# Particle loss: 1.3401, Mask loss: 0.0562, Count loss: 0.0024
# Particle loss: 1.8640, Mask loss: 0.0749, Count loss: 0.0037
# Particle loss: 1.6152, Mask loss: 0.0669, Count loss: 0.0036
# Particle loss: 1.3882, Mask loss: 0.0662, Count loss: 0.0044
# Particle loss: 1.4726, Mask loss: 0.0732, Count loss: 0.0052
# Particle loss: 1.3049, Mask loss: 0.0599, Count loss: 0.0009
# Particle loss: 1.6818, Mask loss: 0.0659, Count loss: 0.0023
# Particle loss: 1.6288, Mask loss: 0.0579, Count loss: 0.0007
# Particle loss: 1.4905, Mask loss: 0.0650, Count loss: 0.0024
# Particle loss: 1.4042, Mask loss: 0.0600, Count loss: 0.0013
# Particle loss: 1.5129, Mask loss: 0.0622, Count loss: 0.0034
# Particle loss: 1.8958, Mask loss: 0.0687, Count loss: 0.0018
# Particle loss: 1.4168, Mask loss: 0.0612, Count loss: 0.0025
# Particle loss: 1.8462, Mask loss: 0.0599, Count loss: 0.0006
# Particle loss: 1.6101, Mask loss: 0.0639, Count loss: 0.0022
# Particle loss: 1.4286, Mask loss: 0.0793, Count loss: 0.0073
# Particle loss: 1.9484, Mask loss: 0.0724, Count loss: 0.0088
# Particle loss: 1.3836, Mask loss: 0.0694, Count loss: 0.0050
# Particle loss: 1.5694, Mask loss: 0.0571, Count loss: 0.0016
# Particle loss: 1.5136, Mask loss: 0.0811, Count loss: 0.0079
# Particle loss: 1.8228, Mask loss: 0.0599, Count loss: 0.0019
# Particle loss: 1.8531, Mask loss: 0.0673, Count loss: 0.0020
# Particle loss: 1.6227, Mask loss: 0.0628, Count loss: 0.0025
# Particle loss: 1.2870, Mask loss: 0.0553, Count loss: 0.0014
# Particle loss: 1.0797, Mask loss: 0.0636, Count loss: 0.0030
# Particle loss: 1.5948, Mask loss: 0.0576, Count loss: 0.0011
# Particle loss: 1.9360, Mask loss: 0.0651, Count loss: 0.0019
# Particle loss: 1.5983, Mask loss: 0.0616, Count loss: 0.0027
# Particle loss: 1.6397, Mask loss: 0.0644, Count loss: 0.0020
# Particle loss: 1.5127, Mask loss: 0.0705, Count loss: 0.0049
# Particle loss: 1.0941, Mask loss: 0.0646, Count loss: 0.0049
# Particle loss: 1.8251, Mask loss: 0.0684, Count loss: 0.0012
# Particle loss: 1.6446, Mask loss: 0.0586, Count loss: 0.0011
# Particle loss: 1.3863, Mask loss: 0.0651, Count loss: 0.0026
# Particle loss: 1.6836, Mask loss: 0.0674, Count loss: 0.0021
# Particle loss: 1.5645, Mask loss: 0.0601, Count loss: 0.0018
# Particle loss: 1.7190, Mask loss: 0.0746, Count loss: 0.0075
# Particle loss: 1.3988, Mask loss: 0.0614, Count loss: 0.0026
# Particle loss: 1.2503, Mask loss: 0.0652, Count loss: 0.0013
# Particle loss: 1.5466, Mask loss: 0.0662, Count loss: 0.0020
# Particle loss: 1.6590, Mask loss: 0.0576, Count loss: 0.0013
# Particle loss: 1.4223, Mask loss: 0.0598, Count loss: 0.0013
# Particle loss: 1.7997, Mask loss: 0.0615, Count loss: 0.0023
# Particle loss: 1.6840, Mask loss: 0.0665, Count loss: 0.0030
# Particle loss: 1.6797, Mask loss: 0.0847, Count loss: 0.0109
# Particle loss: 1.6863, Mask loss: 0.0660, Count loss: 0.0030
# Particle loss: 1.3405, Mask loss: 0.0708, Count loss: 0.0048
# Particle loss: 1.6660, Mask loss: 0.0676, Count loss: 0.0045
# Particle loss: 1.2704, Mask loss: 0.0538, Count loss: 0.0004
# Particle loss: 1.3411, Mask loss: 0.0599, Count loss: 0.0015
# Particle loss: 1.3566, Mask loss: 0.0607, Count loss: 0.0013
# Particle loss: 1.4966, Mask loss: 0.0690, Count loss: 0.0027
# Particle loss: 1.1797, Mask loss: 0.0602, Count loss: 0.0012
# Particle loss: 1.6974, Mask loss: 0.0678, Count loss: 0.0027
# Particle loss: 1.6515, Mask loss: 0.0718, Count loss: 0.0022
# Particle loss: 1.7402, Mask loss: 0.0653, Count loss: 0.0020
# Particle loss: 1.3764, Mask loss: 0.0625, Count loss: 0.0017
# Particle loss: 1.3161, Mask loss: 0.0591, Count loss: 0.0019
# Particle loss: 1.2873, Mask loss: 0.0604, Count loss: 0.0013
# Particle loss: 1.5017, Mask loss: 0.0641, Count loss: 0.0041
# Particle loss: 1.7702, Mask loss: 0.1044, Count loss: 0.0190
# Particle loss: 1.4533, Mask loss: 0.0698, Count loss: 0.0033
# Particle loss: 1.8535, Mask loss: 0.0628, Count loss: 0.0014
# Particle loss: 1.3459, Mask loss: 0.0725, Count loss: 0.0039
# Particle loss: 1.4672, Mask loss: 0.0643, Count loss: 0.0012
# Particle loss: 1.2749, Mask loss: 0.0552, Count loss: 0.0010
# Particle loss: 1.8516, Mask loss: 0.0681, Count loss: 0.0010
# Particle loss: 1.6969, Mask loss: 0.0629, Count loss: 0.0005
# Particle loss: 1.9756, Mask loss: 0.0730, Count loss: 0.0023
# Particle loss: 1.3719, Mask loss: 0.0659, Count loss: 0.0023
# Particle loss: 1.0365, Mask loss: 0.0569, Count loss: 0.0014
# Particle loss: 1.0468, Mask loss: 0.0610, Count loss: 0.0015
# Particle loss: 1.2281, Mask loss: 0.0789, Count loss: 0.0078
# Particle loss: 1.4189, Mask loss: 0.0621, Count loss: 0.0029
# Particle loss: 1.4322, Mask loss: 0.0812, Count loss: 0.0105
# Particle loss: 1.3169, Mask loss: 0.0577, Count loss: 0.0011
# Particle loss: 1.3886, Mask loss: 0.0641, Count loss: 0.0017
# Particle loss: 1.1605, Mask loss: 0.0573, Count loss: 0.0019
# Particle loss: 1.4264, Mask loss: 0.0676, Count loss: 0.0021
# Particle loss: 1.6403, Mask loss: 0.0613, Count loss: 0.0038
# Particle loss: 1.4313, Mask loss: 0.0609, Count loss: 0.0014
# Particle loss: 1.5882, Mask loss: 0.0695, Count loss: 0.0062
# Particle loss: 1.7706, Mask loss: 0.0702, Count loss: 0.0050
# Particle loss: 1.5622, Mask loss: 0.0647, Count loss: 0.0017
# Particle loss: 1.5676, Mask loss: 0.0578, Count loss: 0.0009
# Particle loss: 1.7824, Mask loss: 0.0569, Count loss: 0.0009
# Particle loss: 1.8269, Mask loss: 0.0661, Count loss: 0.0032
# Particle loss: 1.5274, Mask loss: 0.0629, Count loss: 0.0024
# Particle loss: 1.5624, Mask loss: 0.0711, Count loss: 0.0064
# Particle loss: 1.5075, Mask loss: 0.0792, Count loss: 0.0104
# Particle loss: 1.3823, Mask loss: 0.0615, Count loss: 0.0017
# Particle loss: 1.4237, Mask loss: 0.0671, Count loss: 0.0028
# Particle loss: 1.3556, Mask loss: 0.0582, Count loss: 0.0010
# Particle loss: 1.2915, Mask loss: 0.0668, Count loss: 0.0023
# Particle loss: 1.3196, Mask loss: 0.0578, Count loss: 0.0020
# Particle loss: 1.4903, Mask loss: 0.0560, Count loss: 0.0018
# Particle loss: 1.7737, Mask loss: 0.0705, Count loss: 0.0038
# Particle loss: 1.4235, Mask loss: 0.0637, Count loss: 0.0024
# Particle loss: 1.3888, Mask loss: 0.0624, Count loss: 0.0019
# Particle loss: 1.3690, Mask loss: 0.0629, Count loss: 0.0013
# Particle loss: 1.1221, Mask loss: 0.0627, Count loss: 0.0012
# Particle loss: 1.4774, Mask loss: 0.0630, Count loss: 0.0012
# Particle loss: 1.7379, Mask loss: 0.0651, Count loss: 0.0023
# Particle loss: 1.3104, Mask loss: 0.0611, Count loss: 0.0034
# Particle loss: 2.1627, Mask loss: 0.0711, Count loss: 0.0037
# Particle loss: 1.5387, Mask loss: 0.0641, Count loss: 0.0016
# Particle loss: 1.5877, Mask loss: 0.0650, Count loss: 0.0021
# Particle loss: 1.7640, Mask loss: 0.0677, Count loss: 0.0011
# Particle loss: 1.8968, Mask loss: 0.0747, Count loss: 0.0034
# Particle loss: 1.0803, Mask loss: 0.0548, Count loss: 0.0006
# Particle loss: 1.3934, Mask loss: 0.0656, Count loss: 0.0035
# Particle loss: 1.3679, Mask loss: 0.0646, Count loss: 0.0034
# Particle loss: 1.7377, Mask loss: 0.0950, Count loss: 0.0089
# Particle loss: 1.2856, Mask loss: 0.0535, Count loss: 0.0004
# Particle loss: 1.4434, Mask loss: 0.0641, Count loss: 0.0029
# Particle loss: 1.4154, Mask loss: 0.0640, Count loss: 0.0039
# Particle loss: 1.0610, Mask loss: 0.0702, Count loss: 0.0046
# Particle loss: 1.2220, Mask loss: 0.0663, Count loss: 0.0021
# Particle loss: 1.7200, Mask loss: 0.0673, Count loss: 0.0022
# Particle loss: 1.3657, Mask loss: 0.0732, Count loss: 0.0047
# Particle loss: 1.3508, Mask loss: 0.0640, Count loss: 0.0021
# Particle loss: 1.6575, Mask loss: 0.0711, Count loss: 0.0042
# Particle loss: 2.0800, Mask loss: 0.0807, Count loss: 0.0049
# Particle loss: 1.2354, Mask loss: 0.0691, Count loss: 0.0037
# Particle loss: 1.5933, Mask loss: 0.0602, Count loss: 0.0011
# Particle loss: 1.6286, Mask loss: 0.0624, Count loss: 0.0016
# Particle loss: 1.7460, Mask loss: 0.0686, Count loss: 0.0017
# Particle loss: 1.2525, Mask loss: 0.0614, Count loss: 0.0032
# Particle loss: 1.5105, Mask loss: 0.0626, Count loss: 0.0021
# Particle loss: 1.2864, Mask loss: 0.0623, Count loss: 0.0028
# Particle loss: 1.6314, Mask loss: 0.0696, Count loss: 0.0072
# Particle loss: 1.4533, Mask loss: 0.0568, Count loss: 0.0011
# Particle loss: 1.3853, Mask loss: 0.0708, Count loss: 0.0050
# Particle loss: 1.7899, Mask loss: 0.0752, Count loss: 0.0097
# Particle loss: 1.1266, Mask loss: 0.0591, Count loss: 0.0023
# Particle loss: 1.4847, Mask loss: 0.0704, Count loss: 0.0061
# Particle loss: 1.3473, Mask loss: 0.0507, Count loss: 0.0007
# Particle loss: 1.5076, Mask loss: 0.0562, Count loss: 0.0007
# Particle loss: 1.2097, Mask loss: 0.0625, Count loss: 0.0023
# Particle loss: 1.5135, Mask loss: 0.0564, Count loss: 0.0017
# Particle loss: 1.2968, Mask loss: 0.0572, Count loss: 0.0009
# Particle loss: 1.6803, Mask loss: 0.0719, Count loss: 0.0034
# Particle loss: 1.2311, Mask loss: 0.0543, Count loss: 0.0014
# Particle loss: 1.4789, Mask loss: 0.0704, Count loss: 0.0047
# Particle loss: 1.5276, Mask loss: 0.0604, Count loss: 0.0026
# Particle loss: 1.3917, Mask loss: 0.0656, Count loss: 0.0019
# Particle loss: 1.3062, Mask loss: 0.0606, Count loss: 0.0023
# Particle loss: 1.2006, Mask loss: 0.0764, Count loss: 0.0071
# Particle loss: 1.8926, Mask loss: 0.0715, Count loss: 0.0029
# Particle loss: 1.2271, Mask loss: 0.0587, Count loss: 0.0038
# Particle loss: 1.4101, Mask loss: 0.0564, Count loss: 0.0012
# Particle loss: 1.1467, Mask loss: 0.0530, Count loss: 0.0011
# Particle loss: 1.2788, Mask loss: 0.0533, Count loss: 0.0006
# Particle loss: 1.4735, Mask loss: 0.0619, Count loss: 0.0019
# Particle loss: 1.2210, Mask loss: 0.0544, Count loss: 0.0009
# Particle loss: 1.6171, Mask loss: 0.0685, Count loss: 0.0036
# Particle loss: 1.8993, Mask loss: 0.0671, Count loss: 0.0047
# Particle loss: 1.8328, Mask loss: 0.0642, Count loss: 0.0025
# Particle loss: 1.4620, Mask loss: 0.0582, Count loss: 0.0009
# Particle loss: 1.4171, Mask loss: 0.0575, Count loss: 0.0010
# Particle loss: 2.0104, Mask loss: 0.0565, Count loss: 0.0006
# Particle loss: 1.5057, Mask loss: 0.0693, Count loss: 0.0034
# Particle loss: 1.3323, Mask loss: 0.0566, Count loss: 0.0012
# Particle loss: 1.2358, Mask loss: 0.0577, Count loss: 0.0018
# Particle loss: 2.0958, Mask loss: 0.0844, Count loss: 0.0088
# Particle loss: 1.4210, Mask loss: 0.0799, Count loss: 0.0075
# Particle loss: 1.5554, Mask loss: 0.0550, Count loss: 0.0019
# Particle loss: 1.4084, Mask loss: 0.0728, Count loss: 0.0072
# Particle loss: 1.6222, Mask loss: 0.0637, Count loss: 0.0039
# Particle loss: 1.4195, Mask loss: 0.0576, Count loss: 0.0010
# Particle loss: 2.0132, Mask loss: 0.0752, Count loss: 0.0024
# Particle loss: 1.7720, Mask loss: 0.0678, Count loss: 0.0033
# Particle loss: 1.7793, Mask loss: 0.0602, Count loss: 0.0019
# Particle loss: 1.3834, Mask loss: 0.0647, Count loss: 0.0038
# Particle loss: 1.5096, Mask loss: 0.0658, Count loss: 0.0008
# Particle loss: 1.2645, Mask loss: 0.0544, Count loss: 0.0013
# Particle loss: 1.6477, Mask loss: 0.0600, Count loss: 0.0011
# Particle loss: 1.3095, Mask loss: 0.0563, Count loss: 0.0009
# Particle loss: 1.5194, Mask loss: 0.0539, Count loss: 0.0015
# Particle loss: 1.0780, Mask loss: 0.0569, Count loss: 0.0018
# Particle loss: 1.3609, Mask loss: 0.0580, Count loss: 0.0017
# Particle loss: 1.8177, Mask loss: 0.0700, Count loss: 0.0037
# Particle loss: 1.6502, Mask loss: 0.0615, Count loss: 0.0012
# Particle loss: 1.6961, Mask loss: 0.0578, Count loss: 0.0014
# Particle loss: 1.3712, Mask loss: 0.0608, Count loss: 0.0011
# Particle loss: 1.6754, Mask loss: 0.0715, Count loss: 0.0021
# Particle loss: 1.5920, Mask loss: 0.0648, Count loss: 0.0021
# Particle loss: 2.6036, Mask loss: 0.0986, Count loss: 0.0112
# Particle loss: 1.3729, Mask loss: 0.0664, Count loss: 0.0039
# Particle loss: 1.5239, Mask loss: 0.0623, Count loss: 0.0033
# Particle loss: 1.4743, Mask loss: 0.0550, Count loss: 0.0013
# Particle loss: 1.5559, Mask loss: 0.0590, Count loss: 0.0022
# Particle loss: 1.0099, Mask loss: 0.0569, Count loss: 0.0012
# Particle loss: 1.8661, Mask loss: 0.0628, Count loss: 0.0072
# Particle loss: 1.6725, Mask loss: 0.0589, Count loss: 0.0026
# Particle loss: 1.3922, Mask loss: 0.0595, Count loss: 0.0017
# Particle loss: 1.1375, Mask loss: 0.0602, Count loss: 0.0018
# Particle loss: 1.3864, Mask loss: 0.0597, Count loss: 0.0018
# Particle loss: 1.1388, Mask loss: 0.0546, Count loss: 0.0013
# Particle loss: 1.2279, Mask loss: 0.0555, Count loss: 0.0017
# Particle loss: 1.0579, Mask loss: 0.0589, Count loss: 0.0021
# Particle loss: 1.3506, Mask loss: 0.0574, Count loss: 0.0014
# Particle loss: 1.6748, Mask loss: 0.0594, Count loss: 0.0014
# Particle loss: 2.0339, Mask loss: 0.0785, Count loss: 0.0053
# Particle loss: 1.4038, Mask loss: 0.0576, Count loss: 0.0006
# Particle loss: 1.6069, Mask loss: 0.0595, Count loss: 0.0016
# Particle loss: 1.4835, Mask loss: 0.0645, Count loss: 0.0025
# Particle loss: 1.3746, Mask loss: 0.0625, Count loss: 0.0017
# Particle loss: 1.6438, Mask loss: 0.0660, Count loss: 0.0042
# Particle loss: 1.6980, Mask loss: 0.0576, Count loss: 0.0015
# Particle loss: 1.3702, Mask loss: 0.0568, Count loss: 0.0011
# Particle loss: 1.4676, Mask loss: 0.0723, Count loss: 0.0035
# Particle loss: 1.7814, Mask loss: 0.0591, Count loss: 0.0012
# Particle loss: 1.7708, Mask loss: 0.0903, Count loss: 0.0078
# Particle loss: 1.3131, Mask loss: 0.0697, Count loss: 0.0058
# Particle loss: 1.2907, Mask loss: 0.0669, Count loss: 0.0031
# Particle loss: 1.4378, Mask loss: 0.0605, Count loss: 0.0012
# Particle loss: 1.1254, Mask loss: 0.0553, Count loss: 0.0010
# Particle loss: 1.6103, Mask loss: 0.0730, Count loss: 0.0016
# Particle loss: 1.7794, Mask loss: 0.0636, Count loss: 0.0013
# Particle loss: 1.6262, Mask loss: 0.0684, Count loss: 0.0012
# Particle loss: 1.6296, Mask loss: 0.0630, Count loss: 0.0014
# Particle loss: 1.2246, Mask loss: 0.0598, Count loss: 0.0017
# Particle loss: 1.0173, Mask loss: 0.0554, Count loss: 0.0025
# Particle loss: 1.3485, Mask loss: 0.0886, Count loss: 0.0157
# Particle loss: 1.2337, Mask loss: 0.0599, Count loss: 0.0038
# Particle loss: 1.5382, Mask loss: 0.0682, Count loss: 0.0048
# Particle loss: 1.7187, Mask loss: 0.0703, Count loss: 0.0054
# Particle loss: 1.6378, Mask loss: 0.0603, Count loss: 0.0022
# Particle loss: 1.5551, Mask loss: 0.0606, Count loss: 0.0021
# Particle loss: 1.5753, Mask loss: 0.0712, Count loss: 0.0021
# Particle loss: 1.4243, Mask loss: 0.0624, Count loss: 0.0014
# Particle loss: 1.4302, Mask loss: 0.0581, Count loss: 0.0011
# Particle loss: 1.2166, Mask loss: 0.0750, Count loss: 0.0058
# Particle loss: 2.2409, Mask loss: 0.0801, Count loss: 0.0027
# Particle loss: 1.1304, Mask loss: 0.0525, Count loss: 0.0004
# Particle loss: 1.5239, Mask loss: 0.0616, Count loss: 0.0032
# Particle loss: 1.5718, Mask loss: 0.0610, Count loss: 0.0020
# Particle loss: 1.2166, Mask loss: 0.0547, Count loss: 0.0011
# Particle loss: 1.7720, Mask loss: 0.0625, Count loss: 0.0029
# Particle loss: 1.1790, Mask loss: 0.0566, Count loss: 0.0018
# Particle loss: 1.4839, Mask loss: 0.0707, Count loss: 0.0027
# Particle loss: 1.8460, Mask loss: 0.0889, Count loss: 0.0118
# Particle loss: 1.4908, Mask loss: 0.0709, Count loss: 0.0031
# Particle loss: 1.3527, Mask loss: 0.0572, Count loss: 0.0020
# Particle loss: 1.4211, Mask loss: 0.0663, Count loss: 0.0049
# Particle loss: 1.3596, Mask loss: 0.0648, Count loss: 0.0045
# Particle loss: 1.3093, Mask loss: 0.0584, Count loss: 0.0009
# Particle loss: 1.3964, Mask loss: 0.0554, Count loss: 0.0013
# Particle loss: 1.2657, Mask loss: 0.0616, Count loss: 0.0023
# Particle loss: 1.7358, Mask loss: 0.0665, Count loss: 0.0025
# Particle loss: 1.5433, Mask loss: 0.0697, Count loss: 0.0031
# Particle loss: 1.3352, Mask loss: 0.0529, Count loss: 0.0003
# Particle loss: 1.6411, Mask loss: 0.0625, Count loss: 0.0030
# Particle loss: 1.6796, Mask loss: 0.0640, Count loss: 0.0029
# Particle loss: 1.2531, Mask loss: 0.0594, Count loss: 0.0015
# Particle loss: 1.1251, Mask loss: 0.0706, Count loss: 0.0019
# Particle loss: 1.4035, Mask loss: 0.0613, Count loss: 0.0031
# Particle loss: 1.7088, Mask loss: 0.0567, Count loss: 0.0017
# Particle loss: 1.5634, Mask loss: 0.0564, Count loss: 0.0014
# Particle loss: 1.4245, Mask loss: 0.0686, Count loss: 0.0022
# Particle loss: 1.4429, Mask loss: 0.0605, Count loss: 0.0025
# Particle loss: 1.2200, Mask loss: 0.0567, Count loss: 0.0015
# Particle loss: 1.0933, Mask loss: 0.0604, Count loss: 0.0020
# Particle loss: 1.6929, Mask loss: 0.0630, Count loss: 0.0036
# Particle loss: 1.8380, Mask loss: 0.0706, Count loss: 0.0030
# Particle loss: 1.3066, Mask loss: 0.0738, Count loss: 0.0031
# Particle loss: 1.5269, Mask loss: 0.0631, Count loss: 0.0026
# Particle loss: 1.2430, Mask loss: 0.0557, Count loss: 0.0022
# Particle loss: 1.4700, Mask loss: 0.0668, Count loss: 0.0040
# Particle loss: 1.5772, Mask loss: 0.0731, Count loss: 0.0054
# Particle loss: 1.4980, Mask loss: 0.0553, Count loss: 0.0021
# Particle loss: 1.3842, Mask loss: 0.0588, Count loss: 0.0013
# Particle loss: 1.5323, Mask loss: 0.0559, Count loss: 0.0007
# Particle loss: 1.5981, Mask loss: 0.0578, Count loss: 0.0007
# Particle loss: 1.3649, Mask loss: 0.0571, Count loss: 0.0009
# Particle loss: 1.3338, Mask loss: 0.0553, Count loss: 0.0019
# Particle loss: 1.7514, Mask loss: 0.0862, Count loss: 0.0117
# Particle loss: 1.6743, Mask loss: 0.0608, Count loss: 0.0017
# Particle loss: 1.4873, Mask loss: 0.0745, Count loss: 0.0039
# Particle loss: 2.0233, Mask loss: 0.0683, Count loss: 0.0048
# Particle loss: 1.3606, Mask loss: 0.0536, Count loss: 0.0003
# Particle loss: 1.2250, Mask loss: 0.0590, Count loss: 0.0015
# Particle loss: 1.5909, Mask loss: 0.0587, Count loss: 0.0032
# Particle loss: 1.7150, Mask loss: 0.0697, Count loss: 0.0030
# Particle loss: 1.1728, Mask loss: 0.0551, Count loss: 0.0005
# Particle loss: 1.5846, Mask loss: 0.0809, Count loss: 0.0084
# Particle loss: 1.1822, Mask loss: 0.0595, Count loss: 0.0009
# Particle loss: 1.5621, Mask loss: 0.0754, Count loss: 0.0077
# Particle loss: 1.3981, Mask loss: 0.0773, Count loss: 0.0060
# Particle loss: 1.4709, Mask loss: 0.0610, Count loss: 0.0035
# Particle loss: 1.8917, Mask loss: 0.0635, Count loss: 0.0010
# Particle loss: 1.7149, Mask loss: 0.0759, Count loss: 0.0056
# Particle loss: 1.2323, Mask loss: 0.0603, Count loss: 0.0010
# Particle loss: 1.3525, Mask loss: 0.0677, Count loss: 0.0018
# Particle loss: 1.8869, Mask loss: 0.0579, Count loss: 0.0035
# Particle loss: 1.7590, Mask loss: 0.0648, Count loss: 0.0022
# Particle loss: 1.7451, Mask loss: 0.0598, Count loss: 0.0011
# Particle loss: 1.6483, Mask loss: 0.0608, Count loss: 0.0012
# Particle loss: 1.8031, Mask loss: 0.0648, Count loss: 0.0013
# Particle loss: 1.9615, Mask loss: 0.0759, Count loss: 0.0100
# Particle loss: 1.6402, Mask loss: 0.0538, Count loss: 0.0008
# Particle loss: 1.7760, Mask loss: 0.0564, Count loss: 0.0023
# Particle loss: 1.4486, Mask loss: 0.0595, Count loss: 0.0025
# Particle loss: 1.5577, Mask loss: 0.0638, Count loss: 0.0021
# Particle loss: 1.4833, Mask loss: 0.0587, Count loss: 0.0012
# Particle loss: 1.5693, Mask loss: 0.0586, Count loss: 0.0009
# Particle loss: 1.2349, Mask loss: 0.0551, Count loss: 0.0021
# Particle loss: 1.2140, Mask loss: 0.0663, Count loss: 0.0047
# Particle loss: 1.5202, Mask loss: 0.0710, Count loss: 0.0070
# Particle loss: 1.4033, Mask loss: 0.0628, Count loss: 0.0022
# Particle loss: 1.6371, Mask loss: 0.0561, Count loss: 0.0016
# Particle loss: 1.7003, Mask loss: 0.0673, Count loss: 0.0043
# Particle loss: 1.3063, Mask loss: 0.0550, Count loss: 0.0013
# Particle loss: 1.3482, Mask loss: 0.0682, Count loss: 0.0038
# Particle loss: 1.3874, Mask loss: 0.0612, Count loss: 0.0029
# Particle loss: 1.4851, Mask loss: 0.0571, Count loss: 0.0022
# Particle loss: 1.4229, Mask loss: 0.0595, Count loss: 0.0026
# Particle loss: 1.2098, Mask loss: 0.0590, Count loss: 0.0012
# Particle loss: 1.9907, Mask loss: 0.0619, Count loss: 0.0018
# Particle loss: 1.5358, Mask loss: 0.0649, Count loss: 0.0026
# Particle loss: 1.2046, Mask loss: 0.0685, Count loss: 0.0005
# Particle loss: 1.2285, Mask loss: 0.0643, Count loss: 0.0035
# Particle loss: 1.4590, Mask loss: 0.0626, Count loss: 0.0006
# Particle loss: 1.6373, Mask loss: 0.0680, Count loss: 0.0022
# Particle loss: 1.4833, Mask loss: 0.0657, Count loss: 0.0012
# Particle loss: 1.2950, Mask loss: 0.0748, Count loss: 0.0060
# Particle loss: 1.5470, Mask loss: 0.0583, Count loss: 0.0010
# Particle loss: 1.0868, Mask loss: 0.0548, Count loss: 0.0017
# Particle loss: 1.3222, Mask loss: 0.0529, Count loss: 0.0012
# Particle loss: 1.6053, Mask loss: 0.0549, Count loss: 0.0018
# Particle loss: 1.3607, Mask loss: 0.0599, Count loss: 0.0015
# Particle loss: 1.7405, Mask loss: 0.0666, Count loss: 0.0018
# Particle loss: 1.1545, Mask loss: 0.0583, Count loss: 0.0014
# Particle loss: 1.2756, Mask loss: 0.0645, Count loss: 0.0041
# Particle loss: 1.5609, Mask loss: 0.0590, Count loss: 0.0022
# Particle loss: 1.4199, Mask loss: 0.0507, Count loss: 0.0009
# Particle loss: 1.5201, Mask loss: 0.0640, Count loss: 0.0015
# Particle loss: 1.3315, Mask loss: 0.0614, Count loss: 0.0020
# Particle loss: 1.3242, Mask loss: 0.0628, Count loss: 0.0020
# Particle loss: 1.5838, Mask loss: 0.0627, Count loss: 0.0033
# Particle loss: 1.3857, Mask loss: 0.0618, Count loss: 0.0024
# Particle loss: 1.2482, Mask loss: 0.0571, Count loss: 0.0011
# Particle loss: 1.3414, Mask loss: 0.0585, Count loss: 0.0012
# Particle loss: 1.5107, Mask loss: 0.0659, Count loss: 0.0034
# Particle loss: 1.5584, Mask loss: 0.0558, Count loss: 0.0010
# Particle loss: 1.4455, Mask loss: 0.0553, Count loss: 0.0009
# Particle loss: 1.3762, Mask loss: 0.0634, Count loss: 0.0030
# Particle loss: 1.7727, Mask loss: 0.0686, Count loss: 0.0034
# Particle loss: 1.2825, Mask loss: 0.0584, Count loss: 0.0030
# Particle loss: 1.3792, Mask loss: 0.0626, Count loss: 0.0017
# Particle loss: 1.5778, Mask loss: 0.0596, Count loss: 0.0012
# Particle loss: 1.4055, Mask loss: 0.0589, Count loss: 0.0010
# Particle loss: 1.0027, Mask loss: 0.0533, Count loss: 0.0009
# Particle loss: 1.1448, Mask loss: 0.0571, Count loss: 0.0018
# Particle loss: 1.6043, Mask loss: 0.0610, Count loss: 0.0023
# Particle loss: 1.3990, Mask loss: 0.0702, Count loss: 0.0047
# Particle loss: 1.4339, Mask loss: 0.0604, Count loss: 0.0016
# Particle loss: 1.8820, Mask loss: 0.0676, Count loss: 0.0036
# Particle loss: 1.2478, Mask loss: 0.0686, Count loss: 0.0044
# Particle loss: 1.7765, Mask loss: 0.0601, Count loss: 0.0014
# Particle loss: 1.4308, Mask loss: 0.0608, Count loss: 0.0017
# Particle loss: 1.2082, Mask loss: 0.0685, Count loss: 0.0028
# Particle loss: 1.4991, Mask loss: 0.0572, Count loss: 0.0015
# Particle loss: 1.7677, Mask loss: 0.0792, Count loss: 0.0102
# Particle loss: 1.1464, Mask loss: 0.0613, Count loss: 0.0029
# Particle loss: 1.4840, Mask loss: 0.0630, Count loss: 0.0016
# Particle loss: 1.7193, Mask loss: 0.0668, Count loss: 0.0057
# Particle loss: 1.1734, Mask loss: 0.0538, Count loss: 0.0008
# Particle loss: 1.5396, Mask loss: 0.0643, Count loss: 0.0031
# Particle loss: 1.4814, Mask loss: 0.0592, Count loss: 0.0016
# Particle loss: 1.4016, Mask loss: 0.0591, Count loss: 0.0009
# Particle loss: 1.3529, Mask loss: 0.0605, Count loss: 0.0035
# Particle loss: 1.5120, Mask loss: 0.0585, Count loss: 0.0010
# Particle loss: 1.2378, Mask loss: 0.0766, Count loss: 0.0089
# Particle loss: 1.7555, Mask loss: 0.0621, Count loss: 0.0027
# Particle loss: 1.4341, Mask loss: 0.0618, Count loss: 0.0030
# Particle loss: 1.6675, Mask loss: 0.0592, Count loss: 0.0015
# Particle loss: 1.1732, Mask loss: 0.0634, Count loss: 0.0034
# Particle loss: 1.4045, Mask loss: 0.0606, Count loss: 0.0014
# Particle loss: 2.1238, Mask loss: 0.0757, Count loss: 0.0023
# Particle loss: 2.3674, Mask loss: 0.0771, Count loss: 0.0058
# Particle loss: 1.7746, Mask loss: 0.0650, Count loss: 0.0032
# Particle loss: 1.5121, Mask loss: 0.0563, Count loss: 0.0014
# Particle loss: 1.5540, Mask loss: 0.0793, Count loss: 0.0075
# Particle loss: 1.7623, Mask loss: 0.0606, Count loss: 0.0014
# Particle loss: 1.3540, Mask loss: 0.0610, Count loss: 0.0016
# Particle loss: 1.3820, Mask loss: 0.0725, Count loss: 0.0070
# Particle loss: 2.1579, Mask loss: 0.0886, Count loss: 0.0053
# Particle loss: 1.7392, Mask loss: 0.0669, Count loss: 0.0040
# Particle loss: 1.6684, Mask loss: 0.0618, Count loss: 0.0012
# Particle loss: 1.5997, Mask loss: 0.0590, Count loss: 0.0016
# Particle loss: 1.4288, Mask loss: 0.0657, Count loss: 0.0043
# Particle loss: 1.2876, Mask loss: 0.0598, Count loss: 0.0011
# Particle loss: 1.2879, Mask loss: 0.0543, Count loss: 0.0011
# Particle loss: 1.4729, Mask loss: 0.0756, Count loss: 0.0070
# Particle loss: 1.9380, Mask loss: 0.0591, Count loss: 0.0017
# Particle loss: 1.1038, Mask loss: 0.0548, Count loss: 0.0030
# Particle loss: 1.6457, Mask loss: 0.0625, Count loss: 0.0020
# Particle loss: 1.8545, Mask loss: 0.0736, Count loss: 0.0058
# Particle loss: 1.6782, Mask loss: 0.0581, Count loss: 0.0006
# Particle loss: 1.3988, Mask loss: 0.0549, Count loss: 0.0012
# Particle loss: 1.5390, Mask loss: 0.0629, Count loss: 0.0028
# Particle loss: 1.0468, Mask loss: 0.0633, Count loss: 0.0016
# Particle loss: 1.5602, Mask loss: 0.0588, Count loss: 0.0008
# Particle loss: 1.5227, Mask loss: 0.0732, Count loss: 0.0062
# Particle loss: 1.3445, Mask loss: 0.0643, Count loss: 0.0040
# Particle loss: 1.6804, Mask loss: 0.0558, Count loss: 0.0022
# Particle loss: 1.4454, Mask loss: 0.0624, Count loss: 0.0035
# Particle loss: 0.9695, Mask loss: 0.0583, Count loss: 0.0015
# Particle loss: 1.2381, Mask loss: 0.0645, Count loss: 0.0032
# Particle loss: 1.2963, Mask loss: 0.0596, Count loss: 0.0029
# Particle loss: 1.0448, Mask loss: 0.0630, Count loss: 0.0015
# Particle loss: 1.9742, Mask loss: 0.0685, Count loss: 0.0035
# Particle loss: 1.3374, Mask loss: 0.0567, Count loss: 0.0008
# Particle loss: 1.5716, Mask loss: 0.0622, Count loss: 0.0030
# Particle loss: 1.4325, Mask loss: 0.0631, Count loss: 0.0027
# Particle loss: 1.6938, Mask loss: 0.0618, Count loss: 0.0011
# Particle loss: 1.2818, Mask loss: 0.0693, Count loss: 0.0060
# Particle loss: 1.5683, Mask loss: 0.0684, Count loss: 0.0039
# Particle loss: 1.7294, Mask loss: 0.0669, Count loss: 0.0032
# Particle loss: 1.7199, Mask loss: 0.0712, Count loss: 0.0049
# Particle loss: 1.4321, Mask loss: 0.0611, Count loss: 0.0005
# Particle loss: 1.0772, Mask loss: 0.0542, Count loss: 0.0013
# Particle loss: 1.1991, Mask loss: 0.0679, Count loss: 0.0014
# Particle loss: 1.2953, Mask loss: 0.0608, Count loss: 0.0023
# Particle loss: 1.9445, Mask loss: 0.0681, Count loss: 0.0012
# Particle loss: 1.4154, Mask loss: 0.0597, Count loss: 0.0012
# Particle loss: 1.2723, Mask loss: 0.0612, Count loss: 0.0009
# Particle loss: 1.4384, Mask loss: 0.0620, Count loss: 0.0029
# Particle loss: 1.6573, Mask loss: 0.0592, Count loss: 0.0021
# Particle loss: 1.4070, Mask loss: 0.0686, Count loss: 0.0047
# Particle loss: 1.8009, Mask loss: 0.0570, Count loss: 0.0015
# Particle loss: 1.6407, Mask loss: 0.0661, Count loss: 0.0041
# Particle loss: 1.3726, Mask loss: 0.0576, Count loss: 0.0010
# Particle loss: 1.5134, Mask loss: 0.0675, Count loss: 0.0034
# Particle loss: 1.4915, Mask loss: 0.0611, Count loss: 0.0016
# Particle loss: 1.6063, Mask loss: 0.0673, Count loss: 0.0018
# Particle loss: 1.7515, Mask loss: 0.0623, Count loss: 0.0025
# Particle loss: 1.4854, Mask loss: 0.0588, Count loss: 0.0014
# Particle loss: 1.6285, Mask loss: 0.0676, Count loss: 0.0031
# Particle loss: 1.5812, Mask loss: 0.0716, Count loss: 0.0057
# Particle loss: 1.4963, Mask loss: 0.0591, Count loss: 0.0027
# Particle loss: 1.2122, Mask loss: 0.0537, Count loss: 0.0018
# Particle loss: 1.4867, Mask loss: 0.0570, Count loss: 0.0017
# Particle loss: 1.4560, Mask loss: 0.0627, Count loss: 0.0016
# Particle loss: 1.4060, Mask loss: 0.0818, Count loss: 0.0087
# Particle loss: 1.7888, Mask loss: 0.0623, Count loss: 0.0020
# Particle loss: 1.6703, Mask loss: 0.0656, Count loss: 0.0019
# Particle loss: 1.5024, Mask loss: 0.0563, Count loss: 0.0015
# Particle loss: 1.6512, Mask loss: 0.0597, Count loss: 0.0009
# Particle loss: 1.9490, Mask loss: 0.0657, Count loss: 0.0014
# Particle loss: 1.4019, Mask loss: 0.0590, Count loss: 0.0014
# Particle loss: 1.8769, Mask loss: 0.0646, Count loss: 0.0017
# Particle loss: 1.5344, Mask loss: 0.0657, Count loss: 0.0042
# Particle loss: 1.4156, Mask loss: 0.0608, Count loss: 0.0016
# Particle loss: 1.4376, Mask loss: 0.0594, Count loss: 0.0011
# Particle loss: 1.4727, Mask loss: 0.0631, Count loss: 0.0020
# Particle loss: 1.1758, Mask loss: 0.0555, Count loss: 0.0014
# Particle loss: 1.3303, Mask loss: 0.0679, Count loss: 0.0037
# Particle loss: 1.4424, Mask loss: 0.0618, Count loss: 0.0035
# Particle loss: 1.2742, Mask loss: 0.0558, Count loss: 0.0011
#   Learning rate reduced from 0.00083473 to 0.00081889
# Autoencoder Epoch 20/300
#   Loss: 1.590051
#   LR: 0.00081889
#   Best Loss: 1.590051, Patience: 0
#   Learning rate reduced from 0.00081889 to 0.00080250
#   Learning rate reduced from 0.00080250 to 0.00078557
#   Learning rate reduced from 0.00078557 to 0.00076815
#   Learning rate reduced from 0.00076815 to 0.00075025
#   Learning rate reduced from 0.00075025 to 0.00073192
#   Learning rate reduced from 0.00073192 to 0.00071318
#   Learning rate reduced from 0.00071318 to 0.00069406
#   Learning rate reduced from 0.00069406 to 0.00067461
#   Learning rate reduced from 0.00067461 to 0.00065485
# Particle loss: 1.5877, Mask loss: 0.0571, Count loss: 0.0033
# Particle loss: 1.3154, Mask loss: 0.0540, Count loss: 0.0010
# Particle loss: 1.3920, Mask loss: 0.0513, Count loss: 0.0022
# Particle loss: 1.3113, Mask loss: 0.0499, Count loss: 0.0008
# Particle loss: 1.4196, Mask loss: 0.0600, Count loss: 0.0012
# Particle loss: 1.2555, Mask loss: 0.0519, Count loss: 0.0009
# Particle loss: 1.2619, Mask loss: 0.0488, Count loss: 0.0016
# Particle loss: 1.4994, Mask loss: 0.0572, Count loss: 0.0025
# Particle loss: 1.3212, Mask loss: 0.0558, Count loss: 0.0035
# Particle loss: 1.0865, Mask loss: 0.0481, Count loss: 0.0023
# Particle loss: 1.0030, Mask loss: 0.0565, Count loss: 0.0015
# Particle loss: 1.1524, Mask loss: 0.0559, Count loss: 0.0018
# Particle loss: 1.7058, Mask loss: 0.0552, Count loss: 0.0010
# Particle loss: 1.5773, Mask loss: 0.0588, Count loss: 0.0019
# Particle loss: 1.1626, Mask loss: 0.0455, Count loss: 0.0008
# Particle loss: 1.0992, Mask loss: 0.0585, Count loss: 0.0041
# Particle loss: 1.2153, Mask loss: 0.0524, Count loss: 0.0015
# Particle loss: 1.2307, Mask loss: 0.0519, Count loss: 0.0017
# Particle loss: 1.1738, Mask loss: 0.0568, Count loss: 0.0021
# Particle loss: 1.2262, Mask loss: 0.0533, Count loss: 0.0022
# Particle loss: 1.2937, Mask loss: 0.0550, Count loss: 0.0009
# Particle loss: 1.2707, Mask loss: 0.0468, Count loss: 0.0010
# Particle loss: 1.2675, Mask loss: 0.0556, Count loss: 0.0008
# Particle loss: 1.8536, Mask loss: 0.0527, Count loss: 0.0008
# Particle loss: 1.2966, Mask loss: 0.0496, Count loss: 0.0008
# Particle loss: 1.8527, Mask loss: 0.0655, Count loss: 0.0020
# Particle loss: 1.4093, Mask loss: 0.0643, Count loss: 0.0050
# Particle loss: 1.3869, Mask loss: 0.0587, Count loss: 0.0010
# Particle loss: 1.0595, Mask loss: 0.0477, Count loss: 0.0014
# Particle loss: 1.4496, Mask loss: 0.0523, Count loss: 0.0018
# Particle loss: 1.1546, Mask loss: 0.0479, Count loss: 0.0012
# Particle loss: 1.4340, Mask loss: 0.0523, Count loss: 0.0014
# Particle loss: 1.3384, Mask loss: 0.0650, Count loss: 0.0064
# Particle loss: 1.3146, Mask loss: 0.0470, Count loss: 0.0012
# Particle loss: 1.2687, Mask loss: 0.0520, Count loss: 0.0006
# Particle loss: 1.3145, Mask loss: 0.0493, Count loss: 0.0015
# Particle loss: 1.0799, Mask loss: 0.0454, Count loss: 0.0005
# Particle loss: 1.2123, Mask loss: 0.0574, Count loss: 0.0032
# Particle loss: 1.0973, Mask loss: 0.0497, Count loss: 0.0013
# Particle loss: 0.9677, Mask loss: 0.0831, Count loss: 0.0103
# Particle loss: 1.1802, Mask loss: 0.0494, Count loss: 0.0006
# Particle loss: 1.2832, Mask loss: 0.0628, Count loss: 0.0050
# Particle loss: 1.1567, Mask loss: 0.0503, Count loss: 0.0014
# Particle loss: 1.0277, Mask loss: 0.0576, Count loss: 0.0044
# Particle loss: 1.3380, Mask loss: 0.0527, Count loss: 0.0013
# Particle loss: 1.4298, Mask loss: 0.0618, Count loss: 0.0043
# Particle loss: 1.3498, Mask loss: 0.0514, Count loss: 0.0006
# Particle loss: 1.2275, Mask loss: 0.0473, Count loss: 0.0009
# Particle loss: 1.1554, Mask loss: 0.0475, Count loss: 0.0013
# Particle loss: 1.4424, Mask loss: 0.0591, Count loss: 0.0032
# Particle loss: 1.1190, Mask loss: 0.0503, Count loss: 0.0016
# Particle loss: 1.7649, Mask loss: 0.0585, Count loss: 0.0008
# Particle loss: 1.3513, Mask loss: 0.0643, Count loss: 0.0032
# Particle loss: 1.2056, Mask loss: 0.0506, Count loss: 0.0015
# Particle loss: 1.1041, Mask loss: 0.0425, Count loss: 0.0002
# Particle loss: 1.6253, Mask loss: 0.0532, Count loss: 0.0012
# Particle loss: 1.5907, Mask loss: 0.0485, Count loss: 0.0010
# Particle loss: 1.1978, Mask loss: 0.0532, Count loss: 0.0022
# Particle loss: 0.9919, Mask loss: 0.0493, Count loss: 0.0007
# Particle loss: 1.1991, Mask loss: 0.0501, Count loss: 0.0012
# Particle loss: 1.3448, Mask loss: 0.0457, Count loss: 0.0004
# Particle loss: 1.2235, Mask loss: 0.0500, Count loss: 0.0014
# Particle loss: 1.4545, Mask loss: 0.0745, Count loss: 0.0104
# Particle loss: 1.3895, Mask loss: 0.0466, Count loss: 0.0014
# Particle loss: 1.1782, Mask loss: 0.0548, Count loss: 0.0018
# Particle loss: 1.0295, Mask loss: 0.0575, Count loss: 0.0031
# Particle loss: 1.4090, Mask loss: 0.0562, Count loss: 0.0041
# Particle loss: 1.1775, Mask loss: 0.0534, Count loss: 0.0021
# Particle loss: 1.1235, Mask loss: 0.0454, Count loss: 0.0013
# Particle loss: 1.2345, Mask loss: 0.0474, Count loss: 0.0015
# Particle loss: 1.4035, Mask loss: 0.0558, Count loss: 0.0023
# Particle loss: 1.0968, Mask loss: 0.0471, Count loss: 0.0006
# Particle loss: 1.3405, Mask loss: 0.0546, Count loss: 0.0024
# Particle loss: 0.8426, Mask loss: 0.0510, Count loss: 0.0017
# Particle loss: 1.4730, Mask loss: 0.0593, Count loss: 0.0036
# Particle loss: 1.4034, Mask loss: 0.0497, Count loss: 0.0013
# Particle loss: 1.1496, Mask loss: 0.0507, Count loss: 0.0006
# Particle loss: 1.4118, Mask loss: 0.0560, Count loss: 0.0011
# Particle loss: 1.4780, Mask loss: 0.0550, Count loss: 0.0038
# Particle loss: 1.2796, Mask loss: 0.0650, Count loss: 0.0042
# Particle loss: 1.3002, Mask loss: 0.0604, Count loss: 0.0036
# Particle loss: 1.2666, Mask loss: 0.0501, Count loss: 0.0016
# Particle loss: 1.4087, Mask loss: 0.0490, Count loss: 0.0015
# Particle loss: 1.1876, Mask loss: 0.0537, Count loss: 0.0019
# Particle loss: 1.2380, Mask loss: 0.0449, Count loss: 0.0009
# Particle loss: 1.1974, Mask loss: 0.0560, Count loss: 0.0012
# Particle loss: 1.1862, Mask loss: 0.0500, Count loss: 0.0012
# Particle loss: 1.0657, Mask loss: 0.0445, Count loss: 0.0008
# Particle loss: 1.1630, Mask loss: 0.0501, Count loss: 0.0012
# Particle loss: 1.3969, Mask loss: 0.0414, Count loss: 0.0004
# Particle loss: 1.1552, Mask loss: 0.0502, Count loss: 0.0014
# Particle loss: 1.3569, Mask loss: 0.0574, Count loss: 0.0037
# Particle loss: 1.3271, Mask loss: 0.0642, Count loss: 0.0073
# Particle loss: 1.1493, Mask loss: 0.0530, Count loss: 0.0009
# Particle loss: 1.0948, Mask loss: 0.0451, Count loss: 0.0004
# Particle loss: 1.1776, Mask loss: 0.0499, Count loss: 0.0010
# Particle loss: 0.9937, Mask loss: 0.0523, Count loss: 0.0010
# Particle loss: 1.1012, Mask loss: 0.0557, Count loss: 0.0014
# Particle loss: 1.2187, Mask loss: 0.0541, Count loss: 0.0011
# Particle loss: 1.1480, Mask loss: 0.0425, Count loss: 0.0006
# Particle loss: 1.3740, Mask loss: 0.0615, Count loss: 0.0027
# Particle loss: 1.3049, Mask loss: 0.0523, Count loss: 0.0009
# Particle loss: 1.2712, Mask loss: 0.0543, Count loss: 0.0017
# Particle loss: 1.3644, Mask loss: 0.0543, Count loss: 0.0023
# Particle loss: 1.5508, Mask loss: 0.0564, Count loss: 0.0024
# Particle loss: 1.4564, Mask loss: 0.0507, Count loss: 0.0019
# Particle loss: 1.1059, Mask loss: 0.0474, Count loss: 0.0006
# Particle loss: 1.2928, Mask loss: 0.0545, Count loss: 0.0024
# Particle loss: 1.3140, Mask loss: 0.0653, Count loss: 0.0056
# Particle loss: 1.5590, Mask loss: 0.0531, Count loss: 0.0010
# Particle loss: 1.5592, Mask loss: 0.0730, Count loss: 0.0030
# Particle loss: 1.1390, Mask loss: 0.0470, Count loss: 0.0006
# Particle loss: 1.1812, Mask loss: 0.0544, Count loss: 0.0013
# Particle loss: 1.1512, Mask loss: 0.0529, Count loss: 0.0014
# Particle loss: 1.7615, Mask loss: 0.0568, Count loss: 0.0007
# Particle loss: 1.3218, Mask loss: 0.0583, Count loss: 0.0015
# Particle loss: 1.0569, Mask loss: 0.0495, Count loss: 0.0021
# Particle loss: 1.2429, Mask loss: 0.0563, Count loss: 0.0018
# Particle loss: 1.6392, Mask loss: 0.0570, Count loss: 0.0012
# Particle loss: 1.4157, Mask loss: 0.0470, Count loss: 0.0008
# Particle loss: 1.2124, Mask loss: 0.0623, Count loss: 0.0015
# Particle loss: 1.3792, Mask loss: 0.0518, Count loss: 0.0009
# Particle loss: 1.2441, Mask loss: 0.0447, Count loss: 0.0005
# Particle loss: 1.2997, Mask loss: 0.0506, Count loss: 0.0009
# Particle loss: 1.6488, Mask loss: 0.0471, Count loss: 0.0005
# Particle loss: 1.2342, Mask loss: 0.0463, Count loss: 0.0021
# Particle loss: 1.6728, Mask loss: 0.0700, Count loss: 0.0072
# Particle loss: 1.5799, Mask loss: 0.0678, Count loss: 0.0063
# Particle loss: 1.4858, Mask loss: 0.0499, Count loss: 0.0021
# Particle loss: 1.4649, Mask loss: 0.0494, Count loss: 0.0017
# Particle loss: 1.5776, Mask loss: 0.0541, Count loss: 0.0019
# Particle loss: 1.2022, Mask loss: 0.0512, Count loss: 0.0011
# Particle loss: 1.4885, Mask loss: 0.0464, Count loss: 0.0014
# Particle loss: 1.1342, Mask loss: 0.0449, Count loss: 0.0008
# Particle loss: 1.4746, Mask loss: 0.0560, Count loss: 0.0032
# Particle loss: 1.8490, Mask loss: 0.0697, Count loss: 0.0061
# Particle loss: 1.5395, Mask loss: 0.0583, Count loss: 0.0031
# Particle loss: 1.1832, Mask loss: 0.0556, Count loss: 0.0011
# Particle loss: 1.0233, Mask loss: 0.0519, Count loss: 0.0012
# Particle loss: 1.3088, Mask loss: 0.0532, Count loss: 0.0015
# Particle loss: 1.2459, Mask loss: 0.0470, Count loss: 0.0009
# Particle loss: 1.3666, Mask loss: 0.0579, Count loss: 0.0030
# Particle loss: 1.1589, Mask loss: 0.0526, Count loss: 0.0032
# Particle loss: 1.5925, Mask loss: 0.0545, Count loss: 0.0036
# Particle loss: 1.1143, Mask loss: 0.0548, Count loss: 0.0026
# Particle loss: 1.1763, Mask loss: 0.0596, Count loss: 0.0043
# Particle loss: 1.2180, Mask loss: 0.0660, Count loss: 0.0056
# Particle loss: 1.4804, Mask loss: 0.0573, Count loss: 0.0010
# Particle loss: 1.1620, Mask loss: 0.0538, Count loss: 0.0019
# Particle loss: 1.3794, Mask loss: 0.0527, Count loss: 0.0012
# Particle loss: 1.6674, Mask loss: 0.0538, Count loss: 0.0018
# Particle loss: 1.4388, Mask loss: 0.0463, Count loss: 0.0006
# Particle loss: 1.3939, Mask loss: 0.0500, Count loss: 0.0011
# Particle loss: 1.3910, Mask loss: 0.0505, Count loss: 0.0012
# Particle loss: 1.6088, Mask loss: 0.0577, Count loss: 0.0008
# Particle loss: 1.3484, Mask loss: 0.0546, Count loss: 0.0023
# Particle loss: 1.4633, Mask loss: 0.0519, Count loss: 0.0004
# Particle loss: 1.1137, Mask loss: 0.0478, Count loss: 0.0011
# Particle loss: 1.2629, Mask loss: 0.0515, Count loss: 0.0013
# Particle loss: 1.5168, Mask loss: 0.0473, Count loss: 0.0005
# Particle loss: 1.2813, Mask loss: 0.0570, Count loss: 0.0028
# Particle loss: 1.4829, Mask loss: 0.0471, Count loss: 0.0002
# Particle loss: 1.0159, Mask loss: 0.0498, Count loss: 0.0023
# Particle loss: 1.1980, Mask loss: 0.0451, Count loss: 0.0004
# Particle loss: 0.9096, Mask loss: 0.0564, Count loss: 0.0021
# Particle loss: 1.0926, Mask loss: 0.0490, Count loss: 0.0009
# Particle loss: 1.3417, Mask loss: 0.0612, Count loss: 0.0047
# Particle loss: 1.2317, Mask loss: 0.0591, Count loss: 0.0028
# Particle loss: 1.4815, Mask loss: 0.0605, Count loss: 0.0028
# Particle loss: 1.1113, Mask loss: 0.0545, Count loss: 0.0008
# Particle loss: 1.2839, Mask loss: 0.0518, Count loss: 0.0016
# Particle loss: 1.4709, Mask loss: 0.0541, Count loss: 0.0022
# Particle loss: 1.3460, Mask loss: 0.0529, Count loss: 0.0030
# Particle loss: 0.9448, Mask loss: 0.0445, Count loss: 0.0009
# Particle loss: 0.9704, Mask loss: 0.0436, Count loss: 0.0003
# Particle loss: 0.9888, Mask loss: 0.0514, Count loss: 0.0027
# Particle loss: 1.5280, Mask loss: 0.0453, Count loss: 0.0005
# Particle loss: 1.2076, Mask loss: 0.0438, Count loss: 0.0004
# Particle loss: 1.1880, Mask loss: 0.0510, Count loss: 0.0008
# Particle loss: 1.0094, Mask loss: 0.0466, Count loss: 0.0009
# Particle loss: 1.3800, Mask loss: 0.0508, Count loss: 0.0021
# Particle loss: 1.2587, Mask loss: 0.0559, Count loss: 0.0007
# Particle loss: 1.2865, Mask loss: 0.0542, Count loss: 0.0018
# Particle loss: 1.2681, Mask loss: 0.0562, Count loss: 0.0012
# Particle loss: 1.1174, Mask loss: 0.0507, Count loss: 0.0012
# Particle loss: 1.2831, Mask loss: 0.0459, Count loss: 0.0008
# Particle loss: 1.1906, Mask loss: 0.0524, Count loss: 0.0026
# Particle loss: 1.2182, Mask loss: 0.0548, Count loss: 0.0005
# Particle loss: 1.2249, Mask loss: 0.0491, Count loss: 0.0007
# Particle loss: 0.9952, Mask loss: 0.0429, Count loss: 0.0007
# Particle loss: 1.7986, Mask loss: 0.0536, Count loss: 0.0011
# Particle loss: 1.2792, Mask loss: 0.0649, Count loss: 0.0024
# Particle loss: 1.2291, Mask loss: 0.0484, Count loss: 0.0003
# Particle loss: 1.1775, Mask loss: 0.0477, Count loss: 0.0006
# Particle loss: 1.5961, Mask loss: 0.0549, Count loss: 0.0012
# Particle loss: 1.2612, Mask loss: 0.0490, Count loss: 0.0003
# Particle loss: 1.3338, Mask loss: 0.0530, Count loss: 0.0017
# Particle loss: 1.2193, Mask loss: 0.0480, Count loss: 0.0009
# Particle loss: 1.8450, Mask loss: 0.0581, Count loss: 0.0015
# Particle loss: 1.3744, Mask loss: 0.0636, Count loss: 0.0014
# Particle loss: 1.1887, Mask loss: 0.0536, Count loss: 0.0008
# Particle loss: 1.0719, Mask loss: 0.0506, Count loss: 0.0011
# Particle loss: 1.1866, Mask loss: 0.0461, Count loss: 0.0004
# Particle loss: 1.3764, Mask loss: 0.0592, Count loss: 0.0057
# Particle loss: 1.1763, Mask loss: 0.0465, Count loss: 0.0004
# Particle loss: 1.0736, Mask loss: 0.0462, Count loss: 0.0010
# Particle loss: 1.0078, Mask loss: 0.0474, Count loss: 0.0012
# Particle loss: 1.7814, Mask loss: 0.0696, Count loss: 0.0045
# Particle loss: 1.1494, Mask loss: 0.0514, Count loss: 0.0022
# Particle loss: 1.4989, Mask loss: 0.0899, Count loss: 0.0145
# Particle loss: 1.3998, Mask loss: 0.0468, Count loss: 0.0015
# Particle loss: 1.1654, Mask loss: 0.0517, Count loss: 0.0016
# Particle loss: 1.0079, Mask loss: 0.0513, Count loss: 0.0023
# Particle loss: 1.2955, Mask loss: 0.0482, Count loss: 0.0011
# Particle loss: 1.3183, Mask loss: 0.0517, Count loss: 0.0017
# Particle loss: 1.2224, Mask loss: 0.0442, Count loss: 0.0007
# Particle loss: 1.4022, Mask loss: 0.0498, Count loss: 0.0014
# Particle loss: 1.2519, Mask loss: 0.0516, Count loss: 0.0006
# Particle loss: 1.3096, Mask loss: 0.0600, Count loss: 0.0022
# Particle loss: 1.8695, Mask loss: 0.0742, Count loss: 0.0029
# Particle loss: 1.4086, Mask loss: 0.0520, Count loss: 0.0014
# Particle loss: 1.1786, Mask loss: 0.0466, Count loss: 0.0010
# Particle loss: 1.5027, Mask loss: 0.0489, Count loss: 0.0017
# Particle loss: 1.4082, Mask loss: 0.0493, Count loss: 0.0028
# Particle loss: 1.4060, Mask loss: 0.0489, Count loss: 0.0016
# Particle loss: 2.5750, Mask loss: 0.0761, Count loss: 0.0028
# Particle loss: 1.0740, Mask loss: 0.0432, Count loss: 0.0007
# Particle loss: 1.4540, Mask loss: 0.0509, Count loss: 0.0007
# Particle loss: 1.3426, Mask loss: 0.0516, Count loss: 0.0014
# Particle loss: 1.2435, Mask loss: 0.0475, Count loss: 0.0009
# Particle loss: 1.3167, Mask loss: 0.0495, Count loss: 0.0017
# Particle loss: 1.2111, Mask loss: 0.0443, Count loss: 0.0008
# Particle loss: 1.2825, Mask loss: 0.0583, Count loss: 0.0033
# Particle loss: 1.4270, Mask loss: 0.0594, Count loss: 0.0018
# Particle loss: 1.1823, Mask loss: 0.0510, Count loss: 0.0016
# Particle loss: 1.4712, Mask loss: 0.0516, Count loss: 0.0007
# Particle loss: 1.4297, Mask loss: 0.0595, Count loss: 0.0039
# Particle loss: 1.1238, Mask loss: 0.0450, Count loss: 0.0006
# Particle loss: 1.4525, Mask loss: 0.0530, Count loss: 0.0009
# Particle loss: 1.0699, Mask loss: 0.0506, Count loss: 0.0020
# Particle loss: 1.2618, Mask loss: 0.0532, Count loss: 0.0006
# Particle loss: 1.2792, Mask loss: 0.0519, Count loss: 0.0019
# Particle loss: 1.0437, Mask loss: 0.0569, Count loss: 0.0023
# Particle loss: 1.0175, Mask loss: 0.0460, Count loss: 0.0013
# Particle loss: 1.0257, Mask loss: 0.0462, Count loss: 0.0009
# Particle loss: 1.5336, Mask loss: 0.0422, Count loss: 0.0005
# Particle loss: 1.4568, Mask loss: 0.0542, Count loss: 0.0007
# Particle loss: 1.3514, Mask loss: 0.0573, Count loss: 0.0015
# Particle loss: 1.2386, Mask loss: 0.0483, Count loss: 0.0008
# Particle loss: 1.5934, Mask loss: 0.0555, Count loss: 0.0015
# Particle loss: 1.2438, Mask loss: 0.0525, Count loss: 0.0009
# Particle loss: 0.9602, Mask loss: 0.0509, Count loss: 0.0023
# Particle loss: 1.2174, Mask loss: 0.0468, Count loss: 0.0005
# Particle loss: 1.2264, Mask loss: 0.0455, Count loss: 0.0008
# Particle loss: 1.4685, Mask loss: 0.0618, Count loss: 0.0039
# Particle loss: 1.5984, Mask loss: 0.0753, Count loss: 0.0074
# Particle loss: 1.4203, Mask loss: 0.0494, Count loss: 0.0007
# Particle loss: 1.1292, Mask loss: 0.0439, Count loss: 0.0013
# Particle loss: 1.1347, Mask loss: 0.0489, Count loss: 0.0019
# Particle loss: 1.0757, Mask loss: 0.0477, Count loss: 0.0012
# Particle loss: 1.4537, Mask loss: 0.0475, Count loss: 0.0011
# Particle loss: 1.4335, Mask loss: 0.0565, Count loss: 0.0007
# Particle loss: 1.0811, Mask loss: 0.0501, Count loss: 0.0006
# Particle loss: 1.1728, Mask loss: 0.0417, Count loss: 0.0006
# Particle loss: 1.1353, Mask loss: 0.0409, Count loss: 0.0007
# Particle loss: 1.4442, Mask loss: 0.0503, Count loss: 0.0010
# Particle loss: 0.9883, Mask loss: 0.0435, Count loss: 0.0004
# Particle loss: 0.9373, Mask loss: 0.0487, Count loss: 0.0003
# Particle loss: 1.1512, Mask loss: 0.0440, Count loss: 0.0004
# Particle loss: 1.2293, Mask loss: 0.0503, Count loss: 0.0026
# Particle loss: 1.2971, Mask loss: 0.0527, Count loss: 0.0012
# Particle loss: 1.6128, Mask loss: 0.0628, Count loss: 0.0038
# Particle loss: 1.7435, Mask loss: 0.0617, Count loss: 0.0016
# Particle loss: 1.8843, Mask loss: 0.0581, Count loss: 0.0008
# Particle loss: 1.7011, Mask loss: 0.0693, Count loss: 0.0113
# Particle loss: 1.2740, Mask loss: 0.0500, Count loss: 0.0028
# Particle loss: 1.5144, Mask loss: 0.0563, Count loss: 0.0081
# ...
# Particle loss: 0.7822, Mask loss: 0.0327, Count loss: 0.0004
# Particle loss: 0.8667, Mask loss: 0.0376, Count loss: 0.0007
# Particle loss: 1.1791, Mask loss: 0.0345, Count loss: 0.0005
# Particle loss: 0.9810, Mask loss: 0.0371, Count loss: 0.0008
# Particle loss: 0.8904, Mask loss: 0.0349, Count loss: 0.0003
# Particle loss: 0.9171, Mask loss: 0.0409, Count loss: 0.0005
# Particle loss: 0.9162, Mask loss: 0.0312, Count loss: 0.0002
# Particle loss: 0.7457, Mask loss: 0.0340, Count loss: 0.0007
# Particle loss: 0.9477, Mask loss: 0.0305, Count loss: 0.0003
# Particle loss: 0.8614, Mask loss: 0.0456, Count loss: 0.0013
# Particle loss: 1.0448, Mask loss: 0.0408, Count loss: 0.0020
# Particle loss: 1.1745, Mask loss: 0.0386, Count loss: 0.0010
# Particle loss: 0.8326, Mask loss: 0.0348, Count loss: 0.0004
# Particle loss: 0.8147, Mask loss: 0.0369, Count loss: 0.0007
# Particle loss: 0.9591, Mask loss: 0.0354, Count loss: 0.0005
# Particle loss: 0.9651, Mask loss: 0.0367, Count loss: 0.0015
# Particle loss: 0.7746, Mask loss: 0.0337, Count loss: 0.0008
# Particle loss: 0.9527, Mask loss: 0.0426, Count loss: 0.0015
# Particle loss: 1.0027, Mask loss: 0.0341, Count loss: 0.0002
# Particle loss: 0.8586, Mask loss: 0.0371, Count loss: 0.0004
# Particle loss: 1.0242, Mask loss: 0.0425, Count loss: 0.0010
# Particle loss: 0.9681, Mask loss: 0.0337, Count loss: 0.0007
# Particle loss: 1.2079, Mask loss: 0.0336, Count loss: 0.0005
# Particle loss: 0.8935, Mask loss: 0.0372, Count loss: 0.0003
# Particle loss: 1.0266, Mask loss: 0.0404, Count loss: 0.0006
# Particle loss: 0.9939, Mask loss: 0.0304, Count loss: 0.0001
# Particle loss: 0.7959, Mask loss: 0.0355, Count loss: 0.0010
# Particle loss: 0.8442, Mask loss: 0.0503, Count loss: 0.0020
# Particle loss: 0.9795, Mask loss: 0.0364, Count loss: 0.0003
# Particle loss: 0.9327, Mask loss: 0.0342, Count loss: 0.0004
# Particle loss: 0.9466, Mask loss: 0.0354, Count loss: 0.0003
# Particle loss: 1.1743, Mask loss: 0.0373, Count loss: 0.0005
# Particle loss: 0.8403, Mask loss: 0.0308, Count loss: 0.0001
# Particle loss: 1.2148, Mask loss: 0.0341, Count loss: 0.0002
# Particle loss: 1.1077, Mask loss: 0.0487, Count loss: 0.0027
# Particle loss: 1.0453, Mask loss: 0.0377, Count loss: 0.0007
# Particle loss: 0.9044, Mask loss: 0.0421, Count loss: 0.0011
# Particle loss: 0.8085, Mask loss: 0.0352, Count loss: 0.0005
# Particle loss: 0.8691, Mask loss: 0.0318, Count loss: 0.0002
# Particle loss: 1.2139, Mask loss: 0.0403, Count loss: 0.0004
# Particle loss: 0.9230, Mask loss: 0.0364, Count loss: 0.0006
# Particle loss: 0.9656, Mask loss: 0.0361, Count loss: 0.0008
# Particle loss: 0.9217, Mask loss: 0.0348, Count loss: 0.0004
# Particle loss: 0.8349, Mask loss: 0.0355, Count loss: 0.0004
# Particle loss: 0.9346, Mask loss: 0.0321, Count loss: 0.0002
# Particle loss: 1.0524, Mask loss: 0.0338, Count loss: 0.0001
# Particle loss: 1.1226, Mask loss: 0.0399, Count loss: 0.0009
# Particle loss: 0.7390, Mask loss: 0.0339, Count loss: 0.0006
# Particle loss: 1.0222, Mask loss: 0.0390, Count loss: 0.0007
# Particle loss: 1.0248, Mask loss: 0.0394, Count loss: 0.0008
# Particle loss: 0.8541, Mask loss: 0.0368, Count loss: 0.0005
# Particle loss: 1.1274, Mask loss: 0.0319, Count loss: 0.0001
# Particle loss: 0.9354, Mask loss: 0.0338, Count loss: 0.0003
# Particle loss: 0.9571, Mask loss: 0.0336, Count loss: 0.0010
# Particle loss: 0.9210, Mask loss: 0.0384, Count loss: 0.0007
# Particle loss: 1.0034, Mask loss: 0.0511, Count loss: 0.0042
# Particle loss: 0.7771, Mask loss: 0.0336, Count loss: 0.0002
# Particle loss: 0.9133, Mask loss: 0.0380, Count loss: 0.0006
# Particle loss: 1.0835, Mask loss: 0.0378, Count loss: 0.0006
# Particle loss: 0.9485, Mask loss: 0.0341, Count loss: 0.0005
# Particle loss: 1.0137, Mask loss: 0.0396, Count loss: 0.0004
# Particle loss: 1.0401, Mask loss: 0.0363, Count loss: 0.0002
# Particle loss: 1.1666, Mask loss: 0.0380, Count loss: 0.0005
# Particle loss: 1.1879, Mask loss: 0.0310, Count loss: 0.0003
# Particle loss: 0.8440, Mask loss: 0.0362, Count loss: 0.0006
# Particle loss: 0.9306, Mask loss: 0.0329, Count loss: 0.0008
# Particle loss: 0.8861, Mask loss: 0.0405, Count loss: 0.0002
# Particle loss: 0.9188, Mask loss: 0.0480, Count loss: 0.0034
# Particle loss: 0.9906, Mask loss: 0.0394, Count loss: 0.0002
# Particle loss: 0.8642, Mask loss: 0.0323, Count loss: 0.0004
# Particle loss: 0.8787, Mask loss: 0.0305, Count loss: 0.0007
# Particle loss: 0.9484, Mask loss: 0.0353, Count loss: 0.0008
# Particle loss: 1.5214, Mask loss: 0.0414, Count loss: 0.0012
# Particle loss: 0.8451, Mask loss: 0.0293, Count loss: 0.0002
# Particle loss: 0.9680, Mask loss: 0.0385, Count loss: 0.0011
# Particle loss: 0.9734, Mask loss: 0.0339, Count loss: 0.0007
# Particle loss: 1.0112, Mask loss: 0.0329, Count loss: 0.0003
# Particle loss: 0.7738, Mask loss: 0.0378, Count loss: 0.0001
# Particle loss: 0.8663, Mask loss: 0.0326, Count loss: 0.0003
# Particle loss: 0.8389, Mask loss: 0.0311, Count loss: 0.0006
# Particle loss: 0.7756, Mask loss: 0.0333, Count loss: 0.0005
# Particle loss: 0.9376, Mask loss: 0.0359, Count loss: 0.0007
# Particle loss: 1.0574, Mask loss: 0.0536, Count loss: 0.0019
# Particle loss: 0.8508, Mask loss: 0.0333, Count loss: 0.0005
# Particle loss: 1.0461, Mask loss: 0.0338, Count loss: 0.0005
# Particle loss: 0.8744, Mask loss: 0.0321, Count loss: 0.0008
# Particle loss: 0.9884, Mask loss: 0.0374, Count loss: 0.0005
# Particle loss: 1.0553, Mask loss: 0.0378, Count loss: 0.0007
# Particle loss: 0.8134, Mask loss: 0.0414, Count loss: 0.0018
# Particle loss: 0.9195, Mask loss: 0.0340, Count loss: 0.0008
# Particle loss: 0.9084, Mask loss: 0.0381, Count loss: 0.0007
# Particle loss: 1.1396, Mask loss: 0.0368, Count loss: 0.0005
# Particle loss: 1.0342, Mask loss: 0.0461, Count loss: 0.0011
# Particle loss: 0.9178, Mask loss: 0.0376, Count loss: 0.0010
# Particle loss: 0.9240, Mask loss: 0.0361, Count loss: 0.0003
# Particle loss: 1.0581, Mask loss: 0.0429, Count loss: 0.0013
# Particle loss: 0.8308, Mask loss: 0.0378, Count loss: 0.0010
# Particle loss: 1.1686, Mask loss: 0.0465, Count loss: 0.0019
# Particle loss: 0.8735, Mask loss: 0.0390, Count loss: 0.0009
# Particle loss: 1.0671, Mask loss: 0.0413, Count loss: 0.0007
# Particle loss: 0.8501, Mask loss: 0.0333, Count loss: 0.0005
# Particle loss: 0.8982, Mask loss: 0.0306, Count loss: 0.0003
# Particle loss: 1.0901, Mask loss: 0.0369, Count loss: 0.0006
# Particle loss: 0.9980, Mask loss: 0.0423, Count loss: 0.0012
# Particle loss: 0.8879, Mask loss: 0.0304, Count loss: 0.0002
# Particle loss: 0.7564, Mask loss: 0.0309, Count loss: 0.0002
# Particle loss: 0.9952, Mask loss: 0.0343, Count loss: 0.0004
# Particle loss: 1.0110, Mask loss: 0.0351, Count loss: 0.0011
# Particle loss: 1.0167, Mask loss: 0.0367, Count loss: 0.0007
# Particle loss: 0.7933, Mask loss: 0.0334, Count loss: 0.0006
# Particle loss: 1.1497, Mask loss: 0.0365, Count loss: 0.0007
# Particle loss: 0.9523, Mask loss: 0.0350, Count loss: 0.0005
# Particle loss: 0.8316, Mask loss: 0.0283, Count loss: 0.0004
# Particle loss: 1.1147, Mask loss: 0.0363, Count loss: 0.0007
# Particle loss: 0.9037, Mask loss: 0.0309, Count loss: 0.0004
# Particle loss: 1.1451, Mask loss: 0.0402, Count loss: 0.0008
# Particle loss: 1.0419, Mask loss: 0.0510, Count loss: 0.0008
# Particle loss: 0.8681, Mask loss: 0.0303, Count loss: 0.0001
# Particle loss: 1.2289, Mask loss: 0.0426, Count loss: 0.0010
# Particle loss: 0.9730, Mask loss: 0.0361, Count loss: 0.0002
# Particle loss: 1.0421, Mask loss: 0.0384, Count loss: 0.0010
# Particle loss: 0.9710, Mask loss: 0.0363, Count loss: 0.0006
# Particle loss: 1.0648, Mask loss: 0.0370, Count loss: 0.0004
# Particle loss: 1.0954, Mask loss: 0.0367, Count loss: 0.0004
# Particle loss: 1.1522, Mask loss: 0.0386, Count loss: 0.0004
# Particle loss: 0.8849, Mask loss: 0.0335, Count loss: 0.0002
# Particle loss: 0.8751, Mask loss: 0.0307, Count loss: 0.0007
# Particle loss: 0.8507, Mask loss: 0.0342, Count loss: 0.0005
# Particle loss: 1.2145, Mask loss: 0.0348, Count loss: 0.0009
# Particle loss: 0.8378, Mask loss: 0.0330, Count loss: 0.0007
# Particle loss: 0.8129, Mask loss: 0.0337, Count loss: 0.0008
# Particle loss: 1.1326, Mask loss: 0.0408, Count loss: 0.0012
# Particle loss: 0.9349, Mask loss: 0.0335, Count loss: 0.0006
# Particle loss: 0.7348, Mask loss: 0.0409, Count loss: 0.0003
# Particle loss: 0.8558, Mask loss: 0.0336, Count loss: 0.0005
# Particle loss: 0.9514, Mask loss: 0.0350, Count loss: 0.0005
# Particle loss: 1.0329, Mask loss: 0.0310, Count loss: 0.0005
# Particle loss: 1.0466, Mask loss: 0.0380, Count loss: 0.0002
# Particle loss: 0.8645, Mask loss: 0.0330, Count loss: 0.0006
# Particle loss: 1.0899, Mask loss: 0.0417, Count loss: 0.0011
# Particle loss: 1.0642, Mask loss: 0.0491, Count loss: 0.0015
# Particle loss: 1.2011, Mask loss: 0.0541, Count loss: 0.0021
# Particle loss: 0.9617, Mask loss: 0.0351, Count loss: 0.0010
# Particle loss: 0.8224, Mask loss: 0.0342, Count loss: 0.0006
# Particle loss: 1.0326, Mask loss: 0.0429, Count loss: 0.0018
# Particle loss: 1.0015, Mask loss: 0.0293, Count loss: 0.0003
# Particle loss: 0.9532, Mask loss: 0.0393, Count loss: 0.0007
# Particle loss: 1.0599, Mask loss: 0.0364, Count loss: 0.0004
# Particle loss: 1.1803, Mask loss: 0.0489, Count loss: 0.0016
# Particle loss: 1.1699, Mask loss: 0.0391, Count loss: 0.0008
# Particle loss: 0.8215, Mask loss: 0.0300, Count loss: 0.0003
# Particle loss: 0.7957, Mask loss: 0.0323, Count loss: 0.0005
# Particle loss: 0.9004, Mask loss: 0.0328, Count loss: 0.0008
# Particle loss: 1.0519, Mask loss: 0.0362, Count loss: 0.0004
# Particle loss: 0.9096, Mask loss: 0.0397, Count loss: 0.0007
# Particle loss: 1.0122, Mask loss: 0.0362, Count loss: 0.0006
# Particle loss: 1.0845, Mask loss: 0.0401, Count loss: 0.0012
# Particle loss: 0.9426, Mask loss: 0.0334, Count loss: 0.0006
# Particle loss: 0.8565, Mask loss: 0.0328, Count loss: 0.0004
# Particle loss: 0.8715, Mask loss: 0.0382, Count loss: 0.0010
# Particle loss: 0.9449, Mask loss: 0.0410, Count loss: 0.0004
# Particle loss: 1.0362, Mask loss: 0.0356, Count loss: 0.0006
# Particle loss: 1.0339, Mask loss: 0.0472, Count loss: 0.0022
# Particle loss: 1.1076, Mask loss: 0.0342, Count loss: 0.0006
# Particle loss: 1.1891, Mask loss: 0.0419, Count loss: 0.0005
# Particle loss: 0.9006, Mask loss: 0.0326, Count loss: 0.0007
# Particle loss: 1.0715, Mask loss: 0.0342, Count loss: 0.0004
# Particle loss: 1.2058, Mask loss: 0.0477, Count loss: 0.0020
# Particle loss: 1.0931, Mask loss: 0.0400, Count loss: 0.0011
# Particle loss: 0.9039, Mask loss: 0.0445, Count loss: 0.0010
# Particle loss: 1.0866, Mask loss: 0.0389, Count loss: 0.0008
# Particle loss: 1.0962, Mask loss: 0.0391, Count loss: 0.0011
# Particle loss: 1.1226, Mask loss: 0.0369, Count loss: 0.0005
# Particle loss: 0.9325, Mask loss: 0.0410, Count loss: 0.0009
# Particle loss: 0.9289, Mask loss: 0.0401, Count loss: 0.0015
# Particle loss: 0.9170, Mask loss: 0.0345, Count loss: 0.0007
# Particle loss: 1.4908, Mask loss: 0.0498, Count loss: 0.0033
# Particle loss: 1.1254, Mask loss: 0.0369, Count loss: 0.0008
# Particle loss: 0.9949, Mask loss: 0.0349, Count loss: 0.0003
# Particle loss: 1.0613, Mask loss: 0.0367, Count loss: 0.0007
# Particle loss: 0.8988, Mask loss: 0.0439, Count loss: 0.0006
# Particle loss: 0.9457, Mask loss: 0.0439, Count loss: 0.0014
# Particle loss: 1.1123, Mask loss: 0.0464, Count loss: 0.0026
# Particle loss: 0.9086, Mask loss: 0.0303, Count loss: 0.0002
# Particle loss: 1.1221, Mask loss: 0.0355, Count loss: 0.0002
# Particle loss: 1.0816, Mask loss: 0.0361, Count loss: 0.0007
# Particle loss: 0.9779, Mask loss: 0.0381, Count loss: 0.0002
# Particle loss: 1.0728, Mask loss: 0.0333, Count loss: 0.0004
# Particle loss: 0.9466, Mask loss: 0.0370, Count loss: 0.0008
# Particle loss: 1.0829, Mask loss: 0.0390, Count loss: 0.0009
# Particle loss: 1.0261, Mask loss: 0.0375, Count loss: 0.0010
# Particle loss: 0.9600, Mask loss: 0.0342, Count loss: 0.0008
# Particle loss: 0.8605, Mask loss: 0.0323, Count loss: 0.0002
# Particle loss: 0.8635, Mask loss: 0.0373, Count loss: 0.0014
# Particle loss: 1.0107, Mask loss: 0.0322, Count loss: 0.0005
# Particle loss: 0.8773, Mask loss: 0.0448, Count loss: 0.0029
# Particle loss: 0.9549, Mask loss: 0.0321, Count loss: 0.0003
# Particle loss: 1.1021, Mask loss: 0.0407, Count loss: 0.0017
# Particle loss: 0.8581, Mask loss: 0.0397, Count loss: 0.0009
# Particle loss: 1.1467, Mask loss: 0.0419, Count loss: 0.0010
# Particle loss: 0.7997, Mask loss: 0.0311, Count loss: 0.0006
# Particle loss: 0.9476, Mask loss: 0.0387, Count loss: 0.0013
# Particle loss: 1.2235, Mask loss: 0.0474, Count loss: 0.0016
# Particle loss: 0.9430, Mask loss: 0.0377, Count loss: 0.0007
# Particle loss: 1.0295, Mask loss: 0.0349, Count loss: 0.0005
# Particle loss: 0.9965, Mask loss: 0.0327, Count loss: 0.0003
# Particle loss: 1.0568, Mask loss: 0.0306, Count loss: 0.0002
# Particle loss: 0.9033, Mask loss: 0.0379, Count loss: 0.0008
# Particle loss: 0.9725, Mask loss: 0.0347, Count loss: 0.0005
# Particle loss: 1.0339, Mask loss: 0.0363, Count loss: 0.0006
# Particle loss: 0.9978, Mask loss: 0.0358, Count loss: 0.0010
# Particle loss: 1.0037, Mask loss: 0.0393, Count loss: 0.0012
#   Learning rate reduced from 0.00009640 to 0.00010905
# Autoencoder Epoch 90/300
#   Loss: 1.029609
#   LR: 0.00010905
#   Best Loss: 1.012800, Patience: 13
#   Learning rate reduced from 0.00010905 to 0.00012238
#   Learning rate reduced from 0.00012238 to 0.00013638
# Early stopping at epoch 92
#
# === Extracting pooled embeddings ===
#
# === Training diffusion model (batch_size=8) ===
# Training diffusion model with 5000 embeddings...
# Batch size: 8, Batches per epoch: 625
# Diffusion Epoch 0/200, Loss: 1.0041
# Diffusion Epoch 10/200, Loss: 0.9949
# Diffusion Epoch 20/200, Loss: 0.9417
# Diffusion Epoch 30/200, Loss: 0.8705
# Diffusion Epoch 40/200, Loss: 0.8277
# Diffusion Epoch 50/200, Loss: 0.7981
# Diffusion Epoch 60/200, Loss: 0.7679
# Diffusion Epoch 70/200, Loss: 0.7446
# Diffusion Epoch 80/200, Loss: 0.7213
# Diffusion Epoch 90/200, Loss: 0.6994
# Diffusion Epoch 100/200, Loss: 0.6795
# Diffusion Epoch 110/200, Loss: 0.6665
# Diffusion Epoch 120/200, Loss: 0.6459
# Diffusion Epoch 130/200, Loss: 0.6384
# Diffusion Epoch 140/200, Loss: 0.6262
# Diffusion Epoch 150/200, Loss: 0.6110
# Diffusion Epoch 160/200, Loss: 0.6004
# Diffusion Epoch 170/200, Loss: 0.5937
# Diffusion Epoch 180/200, Loss: 0.5807
# Diffusion Epoch 190/200, Loss: 0.5795
#
# === Generating new samples ===
#
# === Visualizing 8 generated jets ===
# === Particle decoder reconstruction comparison ===
# Jet 1 Metrics:
# Wasserstein η: 0.0093, φ: 0.0110, p_T: 0.0035
# KL Divergence η: 9.0098, φ: 9.7815, p_T: 10.6251
# Jet 1 Statistics:
# Original particles: 70
# Reconstructed particles: 70
# Original η range: [-0.332, 0.173]
# Original p_T range: [0.000, 0.205]
# Reconstructed η range: [-0.333, 0.204]
# Reconstructed p_T range: [0.000, 0.280]
#
# Jet 2 Metrics:
# Wasserstein η: 0.0083, φ: 0.0079, p_T: 0.0025
# KL Divergence η: 9.2411, φ: 12.8681, p_T: 11.8496
# Jet 2 Statistics:
# Original particles: 72
# Reconstructed particles: 73
# Original η range: [-0.310, 0.371]
# Original p_T range: [0.000, 0.098]
# Reconstructed η range: [-0.312, 0.364]
# Reconstructed p_T range: [0.000, 0.123]
#
# Jet 3 Metrics:
# Wasserstein η: 0.0123, φ: 0.0092, p_T: 0.0034
# KL Divergence η: 9.3044, φ: 8.8975, p_T: 11.8175
# Jet 3 Statistics:
# Original particles: 75
# Reconstructed particles: 74
# Original η range: [-0.294, 0.364]
# Original p_T range: [0.000, 0.195]
# Reconstructed η range: [-0.308, 0.341]
# Reconstructed p_T range: [0.000, 0.229]
#
#
# Component-wise Average Metrics (over comparisons):
# Wasserstein - η: 0.0100, φ: 0.0093, p_T: 0.0031
# KL Divergence - η: 9.1851, φ: 10.5157, p_T: 11.4307
#
# === Random real jets for comparison ===
# === Summary ===
# Total jets in dataset: 368113
# Successfully processed: 5000
# Processing success rate: 1.4%
# Embedding dimension: 128
# Generated samples: 8
# Max particles per jet: 150
# Batch size used for training: 8
#
# JetNet pipeline completed successfully!
#
# === Generated Jet Analysis ===
# Generated jets - Average particles: 58.62
# Generated jets - Std particles: 40.74
# Generated jets - Range: [4, 111]
# Original jets - Average particles: 54.12
# Original jets - Std particles: 19.68
# Original jets - Range: [27, 75]
